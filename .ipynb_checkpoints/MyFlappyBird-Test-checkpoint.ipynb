# %%
import random
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
from collections import deque
import sys
import cv2
import os

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, Sequential, optimizers, losses, datasets, metrics, callbacks, models

plt.rcParams['font.family'] = ['SimSun']
plt.rcParams['axes.unicode_minus'] = False

sys.path.append(os.path.join('game'))

# print('Headless Mode')
# os.environ["SDL_VIDEODRIVER"] = "dummy"

from IPython.display import clear_output

print(tf.__version__)
# Out:
# 2.4.1

# %% [markdown]
# # 定义参数

# %%
ACTIONS = 2 # number of valid actions

# 模型存放文件夹路径
MODEL_FOLDER = os.path.join("FlappyBird_Model")
MODEL_DIR = os.path.join(MODEL_FOLDER, "FlappyBird_Model.h5")
MODEL_DIR
# Out:
# 'FlappyBird_Model\\FlappyBird_Model.h5'

# %% [markdown]
# # 将游戏返回的图片转为80*80的灰阶图片
# 调整大小 => 灰度化 => 二值化 => 4帧叠加

# %%
# preprocess raw image to 80*80 gray image
def preprocess(observation):
    observation = cv2.cvtColor(cv2.resize(observation, (80, 80)), cv2.COLOR_BGR2GRAY)
    ret, observation = cv2.threshold(observation, 1, 255, cv2.THRESH_BINARY)
    return np.reshape(observation,(80,80,1))

# %% [markdown]
# # 加载模型

# %%
def load_model():
    print('加载模型')
    return models.load_model(MODEL_DIR)

# %% [markdown]
# # 获得下一个Action

# %%
def getAction(model, state, timeStep):
    state_ = tf.expand_dims(state, axis=0)  # 扩展维度 (80,80,4) => (1,80,80,4)
    QValue = model(state_)[0]
    print("步数", timeStep, 'Q值', QValue.numpy(), end='')

    action = np.zeros(ACTIONS)  # 生成[0, 0]初始action
    action_index = 0

    # 按照Q表采取Action
    action_index = np.argmax(QValue)
    action[action_index] = 1

    return action, action_index

# %% [markdown]
# # 打印日志

# %%
def print_info(timeStep, action_index, reward, terminal, score, highest_record):
    action_text = ''
    if action_index == 0:
        action_text = '不跳'
    else:
        action_text = '跳'
    if terminal:
        print("===> 步数", timeStep, "/ 本次行为", action_index, action_text, "/ 本次奖励", reward, "/ Game Over", "/ 累计分数", score, '/ 最高得分', highest_record)
#         sys.__stdout__.write("===> 步数"+str(timeStep)+"/ 本次行为"+str(action_index)+"/ 本次奖励"+str(reward)+"/ Game Over"+"/ 累计分数"+str(score)+ '/ 最高得分'+str(highest_record))
    else:
        print("===> 步数", timeStep, "/ 本次行为", action_index, action_text, "/ 本次奖励", reward, "/ Running", "/ 当前分数", score, '/ 最高得分', highest_record)
#         sys.__stdout__.write("===> 步数"+str(timeStep)+"/ 本次行为"+str(action_index)+"/ 本次奖励"+str(reward)+"/ Running  "+"/ 当前分数"+str(score)+ '/ 最高得分'+str(highest_record))

# %% [markdown]
# # 主流程

# %%
import wrapped_flappy_bird as game

flappyBird = game.GameState()

timeStep = 0 
total_reward = 0
highest_record = 0

# 载入模型
model = load_model()

# 第一次与智能体交互
action = np.array([1, 0])# do nothing
observation0, reward, terminal = flappyBird.frame_step(action)

# 展示第一张图片
plt.imshow(np.rot90(np.rot90(np.rot90(observation0))))
plt.gca().invert_xaxis()
plt.title('The First Picture')
plt.show()

# 处理第一张图片
observation0 = cv2.cvtColor(cv2.resize(observation0, (80, 80)), cv2.COLOR_BGR2GRAY)
ret, observation0 = cv2.threshold(observation0, 1, 255, cv2.THRESH_BINARY)

# 展示第一张图片
plt.imshow(np.rot90(np.rot90(np.rot90(observation0))))
plt.gca().invert_xaxis()
plt.title('The First Picture')
plt.show()

# 第一次的4张图片都是一样的
currentObservation = np.stack((observation0, observation0, observation0, observation0), axis = 2)

while True:
    # 根据上一次的Observation，获得下一次的Action
    action, action_index = getAction(model, currentObservation, timeStep)
    
    # 将Action传入游戏，获得游戏的反馈(状态，奖励，是否GameOver，生效的行为)
    nextObservation, reward, terminal = flappyBird.frame_step(action)

    # 处理图片
    nextObservation = preprocess(nextObservation)
    
    # 将最近的图片后面追加老的前3张图片，从而得到一个新状态
    newObservation = np.append(nextObservation, currentObservation[:,:,:3], axis = 2)
        
    # 计算得分
    if terminal:
        total_reward = 0# Game Over 得分清零
    elif reward == 1:
        total_reward += reward
        
    if highest_record < total_reward:
        highest_record = total_reward

    # 更替状态
    currentObservation = newObservation
    
    # 打印日志
    if timeStep % 1 == 0:
        print_info(timeStep, action_index, reward, terminal, total_reward, highest_record)
        
    # 每第1000次，打印一次图片
    if timeStep % 1000 == 0:
        plt.imshow(np.rot90(np.rot90(np.rot90(currentObservation[:,:,0]))))
        plt.gca().invert_xaxis()
        plt.title('1')
        plt.show()
        
        plt.imshow(np.rot90(np.rot90(np.rot90(currentObservation[:,:,1]))))
        plt.gca().invert_xaxis()
        plt.title('2')
        plt.show()
        
        plt.imshow(np.rot90(np.rot90(np.rot90(currentObservation[:,:,2]))))
        plt.gca().invert_xaxis()
        plt.title('3')
        plt.show()
        
        plt.imshow(np.rot90(np.rot90(np.rot90(currentObservation[:,:,3]))))
        plt.gca().invert_xaxis()
        plt.title('4')
        plt.show()
        
    if timeStep % 10000 == 0:
        clear_output()
        
    timeStep += 1
# Out:
# 步数 40001 Q值 [12.495969   4.1480274]===> 步数 40001 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 175 / 最高得分 833
# 步数 40002 Q值 [12.482353   4.3026295]===> 步数 40002 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 175 / 最高得分 833
# 步数 40003 Q值 [12.540831   5.2235336]===> 步数 40003 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 175 / 最高得分 833
# 步数 40004 Q值 [12.549889   4.2278504]===> 步数 40004 / 本次行为 0 不跳 / 本次奖励 1 / Running   / 当前分数 176 / 最高得分 833
# 步数 40005 Q值 [11.669172   2.8421826]===> 步数 40005 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 176 / 最高得分 833
# 步数 40006 Q值 [11.680698   3.5242257]===> 步数 40006 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 176 / 最高得分 833
# 步数 40007 Q值 [11.739727   5.1111007]===> 步数 40007 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 176 / 最高得分 833
# 步数 40008 Q值 [11.77985    6.7914486]===> 步数 40008 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 176 / 最高得分 833
# 步数 40009 Q值 [11.724137  9.288702]===> 步数 40009 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 176 / 最高得分 833
# 步数 40010 Q值 [11.745419 10.087759]===> 步数 40010 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 176 / 最高得分 833
# 步数 40011 Q值 [11.788089 10.422181]===> 步数 40011 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 176 / 最高得分 833
# 步数 40012 Q值 [11.843466 11.032406]===> 步数 40012 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 176 / 最高得分 833
# 步数 40013 Q值 [11.836897 11.31837 ]===> 步数 40013 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 176 / 最高得分 833
# 步数 40014 Q值 [11.802713 11.297599]===> 步数 40014 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 176 / 最高得分 833
# 步数 40015 Q值 [11.741099 11.435826]===> 步数 40015 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 176 / 最高得分 833
# 步数 40016 Q值 [11.687785 11.356095]===> 步数 40016 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 176 / 最高得分 833
# 步数 40017 Q值 [11.710219 11.448128]===> 步数 40017 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 176 / 最高得分 833
# 步数 40018 Q值 [11.773301 11.080518]===> 步数 40018 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 176 / 最高得分 833
# 步数 40019 Q值 [11.043112 11.499463]===> 步数 40019 / 本次行为 1 跳 / 本次奖励 0.1 / Running   / 当前分数 176 / 最高得分 833
# 步数 40020 Q值 [11.87343   11.8344755]===> 步数 40020 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 176 / 最高得分 833
# 步数 40021 Q值 [11.988206 11.902475]===> 步数 40021 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 176 / 最高得分 833
# 步数 40022 Q值 [12.015808 11.876107]===> 步数 40022 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 176 / 最高得分 833
# 步数 40023 Q值 [12.189599 11.689988]===> 步数 40023 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 176 / 最高得分 833
# 步数 40024 Q值 [12.093979 11.386322]===> 步数 40024 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 176 / 最高得分 833
# 步数 40025 Q值 [12.068553 11.785034]===> 步数 40025 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 176 / 最高得分 833
# 步数 40026 Q值 [12.207059 11.856205]===> 步数 40026 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 176 / 最高得分 833
# 步数 40027 Q值 [12.055346 12.257342]===> 步数 40027 / 本次行为 1 跳 / 本次奖励 0.1 / Running   / 当前分数 176 / 最高得分 833
# 步数 40028 Q值 [12.2766485 11.912418 ]===> 步数 40028 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 176 / 最高得分 833
# 步数 40029 Q值 [12.314796 11.921218]===> 步数 40029 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 176 / 最高得分 833
# 步数 40030 Q值 [12.268965 11.53982 ]===> 步数 40030 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 176 / 最高得分 833
# 步数 40031 Q值 [12.260273 11.489162]===> 步数 40031 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 176 / 最高得分 833
# 步数 40032 Q值 [12.315931 11.015803]===> 步数 40032 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 176 / 最高得分 833
# 步数 40033 Q值 [12.452582 10.580469]===> 步数 40033 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 176 / 最高得分 833
# 步数 40034 Q值 [12.448162 10.453409]===> 步数 40034 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 176 / 最高得分 833
# 步数 40035 Q值 [12.421519  9.930992]===> 步数 40035 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 176 / 最高得分 833
# 步数 40036 Q值 [12.457977  9.249127]===> 步数 40036 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 176 / 最高得分 833
# 步数 40037 Q值 [12.5164795  9.181425 ]===> 步数 40037 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 176 / 最高得分 833
# 步数 40038 Q值 [12.526301  9.816891]===> 步数 40038 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 176 / 最高得分 833
# 步数 40039 Q值 [12.582012 10.683417]===> 步数 40039 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 176 / 最高得分 833
# 步数 40040 Q值 [12.557463 10.811296]===> 步数 40040 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 176 / 最高得分 833
# 步数 40041 Q值 [12.642269 12.198999]===> 步数 40041 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 176 / 最高得分 833
# 步数 40042 Q值 [12.584204 12.33926 ]===> 步数 40042 / 本次行为 0 不跳 / 本次奖励 1 / Running   / 当前分数 177 / 最高得分 833
# 步数 40043 Q值 [11.378802 11.331591]===> 步数 40043 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 177 / 最高得分 833
# 步数 40044 Q值 [ 5.3331246 11.439568 ]===> 步数 40044 / 本次行为 1 跳 / 本次奖励 0.1 / Running   / 当前分数 177 / 最高得分 833
# 步数 40045 Q值 [11.730958 11.134892]===> 步数 40045 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 177 / 最高得分 833
# 步数 40046 Q值 [11.768855 11.086782]===> 步数 40046 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 177 / 最高得分 833
# 步数 40047 Q值 [11.817563 11.143074]===> 步数 40047 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 177 / 最高得分 833
# 步数 40048 Q值 [11.899167 11.197588]===> 步数 40048 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 177 / 最高得分 833
# 步数 40049 Q值 [11.962455 10.938279]===> 步数 40049 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 177 / 最高得分 833
# 步数 40050 Q值 [11.921493 10.366173]===> 步数 40050 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 177 / 最高得分 833
# 步数 40051 Q值 [11.951901 10.166748]===> 步数 40051 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 177 / 最高得分 833
# 步数 40052 Q值 [11.934456 10.02548 ]===> 步数 40052 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 177 / 最高得分 833
# 步数 40053 Q值 [11.910917  8.157413]===> 步数 40053 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 177 / 最高得分 833
# 步数 40054 Q值 [12.089025   5.7010264]===> 步数 40054 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 177 / 最高得分 833
# 步数 40055 Q值 [12.05937   5.215794]===> 步数 40055 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 177 / 最高得分 833
# 步数 40056 Q值 [12.130678   4.3164496]===> 步数 40056 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 177 / 最高得分 833
# 步数 40057 Q值 [12.052761   3.6132073]===> 步数 40057 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 177 / 最高得分 833
# 步数 40058 Q值 [12.112111   3.7894285]===> 步数 40058 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 177 / 最高得分 833
# 步数 40059 Q值 [12.133853   3.3617046]===> 步数 40059 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 177 / 最高得分 833
# 步数 40060 Q值 [12.09952    4.2844634]===> 步数 40060 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 177 / 最高得分 833
# 步数 40061 Q值 [12.114148  5.708861]===> 步数 40061 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 177 / 最高得分 833
# 步数 40062 Q值 [12.108986  5.481865]===> 步数 40062 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 177 / 最高得分 833
# 步数 40063 Q值 [12.0488405  8.723633 ]===> 步数 40063 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 177 / 最高得分 833
# 步数 40064 Q值 [12.195246 11.135704]===> 步数 40064 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 177 / 最高得分 833
# 步数 40065 Q值 [12.071819 11.967307]===> 步数 40065 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 177 / 最高得分 833
# 步数 40066 Q值 [ 9.895052 12.375406]===> 步数 40066 / 本次行为 1 跳 / 本次奖励 0.1 / Running   / 当前分数 177 / 最高得分 833
# 步数 40067 Q值 [12.070321 11.973979]===> 步数 40067 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 177 / 最高得分 833
# 步数 40068 Q值 [12.361389 11.194176]===> 步数 40068 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 177 / 最高得分 833
# 步数 40069 Q值 [12.262875 10.689945]===> 步数 40069 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 177 / 最高得分 833
# 步数 40070 Q值 [12.358097 10.116823]===> 步数 40070 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 177 / 最高得分 833
# 步数 40071 Q值 [12.518823   9.5083065]===> 步数 40071 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 177 / 最高得分 833
# 步数 40072 Q值 [12.558744  8.584034]===> 步数 40072 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 177 / 最高得分 833
# 步数 40073 Q值 [12.585915  6.700369]===> 步数 40073 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 177 / 最高得分 833
# 步数 40074 Q值 [12.549171   6.6511483]===> 步数 40074 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 177 / 最高得分 833
# 步数 40075 Q值 [12.588544  6.261786]===> 步数 40075 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 177 / 最高得分 833
# 步数 40076 Q值 [12.633878  6.073725]===> 步数 40076 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 177 / 最高得分 833
# 步数 40077 Q值 [12.695952   6.7485948]===> 步数 40077 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 177 / 最高得分 833
# 步数 40078 Q值 [12.684327  8.999324]===> 步数 40078 / 本次行为 0 不跳 / 本次奖励 1 / Running   / 当前分数 178 / 最高得分 833
# 步数 40079 Q值 [11.8389635  9.084011 ]===> 步数 40079 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 178 / 最高得分 833
# 步数 40080 Q值 [11.8311    9.860784]===> 步数 40080 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 178 / 最高得分 833
# 步数 40081 Q值 [11.880586 11.120046]===> 步数 40081 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 178 / 最高得分 833
# 步数 40082 Q值 [11.857823 11.28646 ]===> 步数 40082 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 178 / 最高得分 833
# 步数 40083 Q值 [10.422388 11.989449]===> 步数 40083 / 本次行为 1 跳 / 本次奖励 0.1 / Running   / 当前分数 178 / 最高得分 833
# 步数 40084 Q值 [11.928823 11.646605]===> 步数 40084 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 178 / 最高得分 833
# 步数 40085 Q值 [11.92588  11.512431]===> 步数 40085 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 178 / 最高得分 833
# 步数 40086 Q值 [11.959727 11.0842  ]===> 步数 40086 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 178 / 最高得分 833
# 步数 40087 Q值 [11.912073 10.299881]===> 步数 40087 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 178 / 最高得分 833
# 步数 40088 Q值 [11.948971  9.726278]===> 步数 40088 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 178 / 最高得分 833
# 步数 40089 Q值 [11.954867  9.020365]===> 步数 40089 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 178 / 最高得分 833
# 步数 40090 Q值 [11.96324   8.013155]===> 步数 40090 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 178 / 最高得分 833
# 步数 40091 Q值 [12.002782  4.433687]===> 步数 40091 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 178 / 最高得分 833
# 步数 40092 Q值 [11.973485  3.084889]===> 步数 40092 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 178 / 最高得分 833
# 步数 40093 Q值 [11.960178   1.6507567]===> 步数 40093 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 178 / 最高得分 833
# 步数 40094 Q值 [12.124934    0.99931836]===> 步数 40094 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 178 / 最高得分 833
# 步数 40095 Q值 [12.127724    0.08905433]===> 步数 40095 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 178 / 最高得分 833
# 步数 40096 Q值 [12.038501  -0.5322343]===> 步数 40096 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 178 / 最高得分 833
# 步数 40097 Q值 [12.131551   -0.39835817]===> 步数 40097 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 178 / 最高得分 833
# 步数 40098 Q值 [12.220821   -0.12754185]===> 步数 40098 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 178 / 最高得分 833
# 步数 40099 Q值 [12.130643    0.59567946]===> 步数 40099 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 178 / 最高得分 833
# 步数 40100 Q值 [12.184425   1.4646709]===> 步数 40100 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 178 / 最高得分 833
# 步数 40101 Q值 [12.166863  2.729072]===> 步数 40101 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 178 / 最高得分 833
# 步数 40102 Q值 [12.257365  5.465712]===> 步数 40102 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 178 / 最高得分 833
# 步数 40103 Q值 [12.310079  8.664454]===> 步数 40103 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 178 / 最高得分 833
# 步数 40104 Q值 [12.244771 10.725253]===> 步数 40104 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 178 / 最高得分 833
# 步数 40105 Q值 [12.362152  11.7667465]===> 步数 40105 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 178 / 最高得分 833
# 步数 40106 Q值 [10.667479 12.395996]===> 步数 40106 / 本次行为 1 跳 / 本次奖励 0.1 / Running   / 当前分数 178 / 最高得分 833
# 步数 40107 Q值 [12.441947 10.68354 ]===> 步数 40107 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 178 / 最高得分 833
# 步数 40108 Q值 [12.404397 10.462438]===> 步数 40108 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 178 / 最高得分 833
# 步数 40109 Q值 [12.57219   9.567147]===> 步数 40109 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 178 / 最高得分 833
# 步数 40110 Q值 [12.583764   7.4325476]===> 步数 40110 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 178 / 最高得分 833
# 步数 40111 Q值 [12.661845  7.133914]===> 步数 40111 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 178 / 最高得分 833
# 步数 40112 Q值 [12.469296   5.6777015]===> 步数 40112 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 178 / 最高得分 833
# 步数 40113 Q值 [12.564874  5.455599]===> 步数 40113 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 178 / 最高得分 833
# 步数 40114 Q值 [12.567056  5.47569 ]===> 步数 40114 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 178 / 最高得分 833
# 步数 40115 Q值 [12.63186   5.759324]===> 步数 40115 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 178 / 最高得分 833
# 步数 40116 Q值 [12.58882  5.68209]===> 步数 40116 / 本次行为 0 不跳 / 本次奖励 1 / Running   / 当前分数 179 / 最高得分 833
# 步数 40117 Q值 [11.702021   4.6919513]===> 步数 40117 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 179 / 最高得分 833
# 步数 40118 Q值 [11.783963   6.4500136]===> 步数 40118 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 179 / 最高得分 833
# 步数 40119 Q值 [11.827894   7.8872256]===> 步数 40119 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 179 / 最高得分 833
# 步数 40120 Q值 [11.833885   9.3868685]===> 步数 40120 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 179 / 最高得分 833
# 步数 40121 Q值 [11.859245  10.2109375]===> 步数 40121 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 179 / 最高得分 833
# 步数 40122 Q值 [11.936307 10.950376]===> 步数 40122 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 179 / 最高得分 833
# 步数 40123 Q值 [11.790773 11.532001]===> 步数 40123 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 179 / 最高得分 833
# 步数 40124 Q值 [11.698367 11.698346]===> 步数 40124 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 179 / 最高得分 833
# 步数 40125 Q值 [11.616602 11.547467]===> 步数 40125 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 179 / 最高得分 833
# 步数 40126 Q值 [11.4539   11.645714]===> 步数 40126 / 本次行为 1 跳 / 本次奖励 0.1 / Running   / 当前分数 179 / 最高得分 833
# 步数 40127 Q值 [11.930507  11.0805435]===> 步数 40127 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 179 / 最高得分 833
# 步数 40128 Q值 [11.943383 11.019156]===> 步数 40128 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 179 / 最高得分 833
# 步数 40129 Q值 [11.94741  11.588366]===> 步数 40129 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 179 / 最高得分 833
# 步数 40130 Q值 [11.995894 11.80538 ]===> 步数 40130 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 179 / 最高得分 833
# 步数 40131 Q值 [12.012751 11.945075]===> 步数 40131 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 179 / 最高得分 833
# 步数 40132 Q值 [12.140094 12.363628]===> 步数 40132 / 本次行为 1 跳 / 本次奖励 0.1 / Running   / 当前分数 179 / 最高得分 833
# 步数 40133 Q值 [12.156462 12.123613]===> 步数 40133 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 179 / 最高得分 833
# 步数 40134 Q值 [12.207486 12.01075 ]===> 步数 40134 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 179 / 最高得分 833
# 步数 40135 Q值 [12.192066 12.198019]===> 步数 40135 / 本次行为 1 跳 / 本次奖励 0.1 / Running   / 当前分数 179 / 最高得分 833
# 步数 40136 Q值 [12.172682 11.973841]===> 步数 40136 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 179 / 最高得分 833
# 步数 40137 Q值 [12.143572 11.486884]===> 步数 40137 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 179 / 最高得分 833
# 步数 40138 Q值 [12.050359 10.903897]===> 步数 40138 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 179 / 最高得分 833
# 步数 40139 Q值 [12.043665  9.007422]===> 步数 40139 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 179 / 最高得分 833
# 步数 40140 Q值 [12.238171   6.6268554]===> 步数 40140 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 179 / 最高得分 833
# 步数 40141 Q值 [12.328793  7.233864]===> 步数 40141 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 179 / 最高得分 833
# 步数 40142 Q值 [12.456634  7.653942]===> 步数 40142 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 179 / 最高得分 833
# 步数 40143 Q值 [12.474     7.003942]===> 步数 40143 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 179 / 最高得分 833
# 步数 40144 Q值 [12.399847  6.310334]===> 步数 40144 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 179 / 最高得分 833
# 步数 40145 Q值 [12.515971  5.074085]===> 步数 40145 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 179 / 最高得分 833
# 步数 40146 Q值 [12.438813   6.1313486]===> 步数 40146 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 179 / 最高得分 833
# 步数 40147 Q值 [12.487056   5.5590487]===> 步数 40147 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 179 / 最高得分 833
# 步数 40148 Q值 [12.544239   6.1764812]===> 步数 40148 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 179 / 最高得分 833
# 步数 40149 Q值 [12.550179  8.187758]===> 步数 40149 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 179 / 最高得分 833
# 步数 40150 Q值 [12.529272 10.350895]===> 步数 40150 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 179 / 最高得分 833
# 步数 40151 Q值 [12.567784 11.461726]===> 步数 40151 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 179 / 最高得分 833
# 步数 40152 Q值 [12.276424 12.543272]===> 步数 40152 / 本次行为 1 跳 / 本次奖励 1 / Running   / 当前分数 180 / 最高得分 833
# 步数 40153 Q值 [11.803652 10.162724]===> 步数 40153 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 180 / 最高得分 833
# 步数 40154 Q值 [11.706678  9.650097]===> 步数 40154 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 180 / 最高得分 833
# 步数 40155 Q值 [11.750565  8.336312]===> 步数 40155 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 180 / 最高得分 833
# 步数 40156 Q值 [11.864859  9.201656]===> 步数 40156 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 180 / 最高得分 833
# 步数 40157 Q值 [11.959633   7.8250823]===> 步数 40157 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 180 / 最高得分 833
# 步数 40158 Q值 [11.972422  7.309008]===> 步数 40158 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 180 / 最高得分 833
# 步数 40159 Q值 [11.913304  6.72067 ]===> 步数 40159 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 180 / 最高得分 833
# 步数 40160 Q值 [11.884291  5.831926]===> 步数 40160 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 180 / 最高得分 833
# 步数 40161 Q值 [11.951742   5.5630174]===> 步数 40161 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 180 / 最高得分 833
# 步数 40162 Q值 [11.844274   4.8853536]===> 步数 40162 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 180 / 最高得分 833
# 步数 40163 Q值 [11.77334   4.452263]===> 步数 40163 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 180 / 最高得分 833
# 步数 40164 Q值 [11.891463  4.382285]===> 步数 40164 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 180 / 最高得分 833
# 步数 40165 Q值 [11.873059   4.8400397]===> 步数 40165 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 180 / 最高得分 833
# 步数 40166 Q值 [11.954411   5.9595428]===> 步数 40166 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 180 / 最高得分 833
# 步数 40167 Q值 [11.9286785  6.1039147]===> 步数 40167 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 180 / 最高得分 833
# 步数 40168 Q值 [11.959257   5.2467685]===> 步数 40168 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 180 / 最高得分 833
# 步数 40169 Q值 [12.014266  4.014008]===> 步数 40169 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 180 / 最高得分 833
# 步数 40170 Q值 [12.058037   5.0592914]===> 步数 40170 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 180 / 最高得分 833
# 步数 40171 Q值 [12.0624075  6.503553 ]===> 步数 40171 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 180 / 最高得分 833
# 步数 40172 Q值 [12.1713915  7.6043863]===> 步数 40172 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 180 / 最高得分 833
# 步数 40173 Q值 [12.159747 10.519675]===> 步数 40173 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 180 / 最高得分 833
# 步数 40174 Q值 [12.112226 11.458507]===> 步数 40174 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 180 / 最高得分 833
# 步数 40175 Q值 [11.973796 12.349053]===> 步数 40175 / 本次行为 1 跳 / 本次奖励 0.1 / Running   / 当前分数 180 / 最高得分 833
# 步数 40176 Q值 [12.366739 12.533997]===> 步数 40176 / 本次行为 1 跳 / 本次奖励 0.1 / Running   / 当前分数 180 / 最高得分 833
# 步数 40177 Q值 [12.347336 11.977669]===> 步数 40177 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 180 / 最高得分 833
# 步数 40178 Q值 [12.281235 11.394897]===> 步数 40178 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 180 / 最高得分 833
# 步数 40179 Q值 [12.297368 10.849962]===> 步数 40179 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 180 / 最高得分 833
# 步数 40180 Q值 [12.366175 10.2919  ]===> 步数 40180 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 180 / 最高得分 833
# 步数 40181 Q值 [12.402906  9.124829]===> 步数 40181 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 180 / 最高得分 833
# 步数 40182 Q值 [12.411483  8.151514]===> 步数 40182 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 180 / 最高得分 833
# 步数 40183 Q值 [12.400486   5.1255665]===> 步数 40183 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 180 / 最高得分 833
# 步数 40184 Q值 [12.501801  4.251853]===> 步数 40184 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 180 / 最高得分 833
# 步数 40185 Q值 [12.551893  3.546722]===> 步数 40185 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 180 / 最高得分 833
# 步数 40186 Q值 [12.458138   2.9147854]===> 步数 40186 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 180 / 最高得分 833
# 步数 40187 Q值 [12.503723  3.075781]===> 步数 40187 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 180 / 最高得分 833
# 步数 40188 Q值 [12.593946  3.810895]===> 步数 40188 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 180 / 最高得分 833
# 步数 40189 Q值 [12.4922695  7.267007 ]===> 步数 40189 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 180 / 最高得分 833
# 步数 40190 Q值 [12.450387  8.195449]===> 步数 40190 / 本次行为 0 不跳 / 本次奖励 1 / Running   / 当前分数 181 / 最高得分 833
# 步数 40191 Q值 [11.537509 10.477492]===> 步数 40191 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 181 / 最高得分 833
# 步数 40192 Q值 [11.221436  11.2006445]===> 步数 40192 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 181 / 最高得分 833
# 步数 40193 Q值 [11.575988 11.391677]===> 步数 40193 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 181 / 最高得分 833
# 步数 40194 Q值 [10.786565 11.664435]===> 步数 40194 / 本次行为 1 跳 / 本次奖励 0.1 / Running   / 当前分数 181 / 最高得分 833
# 步数 40195 Q值 [11.735571 11.314344]===> 步数 40195 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 181 / 最高得分 833
# 步数 40196 Q值 [11.8059635 11.235529 ]===> 步数 40196 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 181 / 最高得分 833
# 步数 40197 Q值 [11.76565  11.026796]===> 步数 40197 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 181 / 最高得分 833
# 步数 40198 Q值 [11.773734 10.602708]===> 步数 40198 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 181 / 最高得分 833
# 步数 40199 Q值 [11.800669 10.350029]===> 步数 40199 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 181 / 最高得分 833
# 步数 40200 Q值 [11.841182 10.378345]===> 步数 40200 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 181 / 最高得分 833
# 步数 40201 Q值 [11.901254  9.993014]===> 步数 40201 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 181 / 最高得分 833
# 步数 40202 Q值 [11.999135  9.496455]===> 步数 40202 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 181 / 最高得分 833
# 步数 40203 Q值 [12.045614  9.210863]===> 步数 40203 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 181 / 最高得分 833
# 步数 40204 Q值 [12.03825   9.500129]===> 步数 40204 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 181 / 最高得分 833
# 步数 40205 Q值 [11.976855  8.778833]===> 步数 40205 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 181 / 最高得分 833
# 步数 40206 Q值 [12.003734   7.9875417]===> 步数 40206 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 181 / 最高得分 833
# 步数 40207 Q值 [12.103942   7.5640926]===> 步数 40207 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 181 / 最高得分 833
# 步数 40208 Q值 [12.26446   8.869183]===> 步数 40208 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 181 / 最高得分 833
# 步数 40209 Q值 [12.208569  9.653206]===> 步数 40209 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 181 / 最高得分 833
# 步数 40210 Q值 [12.138505 10.390419]===> 步数 40210 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 181 / 最高得分 833
# 步数 40211 Q值 [12.057623 11.52886 ]===> 步数 40211 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 181 / 最高得分 833
# 步数 40212 Q值 [11.749093 12.070926]===> 步数 40212 / 本次行为 1 跳 / 本次奖励 0.1 / Running   / 当前分数 181 / 最高得分 833
# 步数 40213 Q值 [12.174745 11.946522]===> 步数 40213 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 181 / 最高得分 833
# 步数 40214 Q值 [12.188481 10.861559]===> 步数 40214 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 181 / 最高得分 833
# 步数 40215 Q值 [12.323432 10.938492]===> 步数 40215 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 181 / 最高得分 833
# 步数 40216 Q值 [12.47588   9.894747]===> 步数 40216 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 181 / 最高得分 833
# 步数 40217 Q值 [12.523433  7.357414]===> 步数 40217 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 181 / 最高得分 833
# 步数 40218 Q值 [12.488093   5.5222216]===> 步数 40218 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 181 / 最高得分 833
# 步数 40219 Q值 [12.491364  4.997698]===> 步数 40219 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 181 / 最高得分 833
# 步数 40220 Q值 [12.500752   4.0799594]===> 步数 40220 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 181 / 最高得分 833
# 步数 40221 Q值 [12.473627   2.8451443]===> 步数 40221 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 181 / 最高得分 833
# 步数 40222 Q值 [12.506598   2.7631652]===> 步数 40222 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 181 / 最高得分 833
# 步数 40223 Q值 [12.4722805  2.4074416]===> 步数 40223 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 181 / 最高得分 833
# 步数 40224 Q值 [12.431383   3.8489537]===> 步数 40224 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 181 / 最高得分 833
# 步数 40225 Q值 [12.56908   6.205411]===> 步数 40225 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 181 / 最高得分 833
# 步数 40226 Q值 [12.620521   7.4570312]===> 步数 40226 / 本次行为 0 不跳 / 本次奖励 1 / Running   / 当前分数 182 / 最高得分 833
# 步数 40227 Q值 [11.679616  8.957628]===> 步数 40227 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 182 / 最高得分 833
# 步数 40228 Q值 [11.614767 10.303211]===> 步数 40228 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 182 / 最高得分 833
# 步数 40229 Q值 [11.600836 11.279741]===> 步数 40229 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 182 / 最高得分 833
# 步数 40230 Q值 [ 7.3895836 11.774178 ]===> 步数 40230 / 本次行为 1 跳 / 本次奖励 0.1 / Running   / 当前分数 182 / 最高得分 833
# 步数 40231 Q值 [11.626303 11.013387]===> 步数 40231 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 182 / 最高得分 833
# 步数 40232 Q值 [11.5976305 10.5773325]===> 步数 40232 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 182 / 最高得分 833
# 步数 40233 Q值 [11.624657 10.84093 ]===> 步数 40233 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 182 / 最高得分 833
# 步数 40234 Q值 [11.619888 10.075576]===> 步数 40234 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 182 / 最高得分 833
# 步数 40235 Q值 [11.685862  9.049507]===> 步数 40235 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 182 / 最高得分 833
# 步数 40236 Q值 [11.788983   8.1058035]===> 步数 40236 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 182 / 最高得分 833
# 步数 40237 Q值 [11.810989  6.456008]===> 步数 40237 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 182 / 最高得分 833
# 步数 40238 Q值 [11.782338  5.329469]===> 步数 40238 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 182 / 最高得分 833
# 步数 40239 Q值 [11.800519  6.006728]===> 步数 40239 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 182 / 最高得分 833
# 步数 40240 Q值 [11.794564   6.5940547]===> 步数 40240 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 182 / 最高得分 833
# 步数 40241 Q值 [11.9421625  6.6004453]===> 步数 40241 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 182 / 最高得分 833
# 步数 40242 Q值 [12.018717   6.0309753]===> 步数 40242 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 182 / 最高得分 833
# 步数 40243 Q值 [12.025429  6.033063]===> 步数 40243 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 182 / 最高得分 833
# 步数 40244 Q值 [12.004208  6.095683]===> 步数 40244 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 182 / 最高得分 833
# 步数 40245 Q值 [11.988384  5.895293]===> 步数 40245 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 182 / 最高得分 833
# 步数 40246 Q值 [12.085885  6.592346]===> 步数 40246 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 182 / 最高得分 833
# 步数 40247 Q值 [12.013355   7.4938607]===> 步数 40247 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 182 / 最高得分 833
# 步数 40248 Q值 [12.057655  8.994001]===> 步数 40248 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 182 / 最高得分 833
# 步数 40249 Q值 [11.965662 10.864494]===> 步数 40249 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 182 / 最高得分 833
# 步数 40250 Q值 [11.555354 12.289998]===> 步数 40250 / 本次行为 1 跳 / 本次奖励 0.1 / Running   / 当前分数 182 / 最高得分 833
# 步数 40251 Q值 [12.072186 12.267577]===> 步数 40251 / 本次行为 1 跳 / 本次奖励 0.1 / Running   / 当前分数 182 / 最高得分 833
# 步数 40252 Q值 [12.14378  10.923869]===> 步数 40252 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 182 / 最高得分 833
# 步数 40253 Q值 [12.189004 10.698275]===> 步数 40253 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 182 / 最高得分 833
# 步数 40254 Q值 [12.279305  8.665606]===> 步数 40254 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 182 / 最高得分 833
# 步数 40255 Q值 [12.378691  6.90164 ]===> 步数 40255 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 182 / 最高得分 833
# 步数 40256 Q值 [12.494538  4.859258]===> 步数 40256 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 182 / 最高得分 833
# 步数 40257 Q值 [12.54777   5.530415]===> 步数 40257 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 182 / 最高得分 833
# 步数 40258 Q值 [12.520975   3.3650959]===> 步数 40258 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 182 / 最高得分 833
# 步数 40259 Q值 [12.483555   2.3928864]===> 步数 40259 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 182 / 最高得分 833
# 步数 40260 Q值 [12.551617   2.4605129]===> 步数 40260 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 182 / 最高得分 833
# 步数 40261 Q值 [12.590311   2.1827877]===> 步数 40261 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 182 / 最高得分 833
# 步数 40262 Q值 [12.608181   2.5394201]===> 步数 40262 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 182 / 最高得分 833
# 步数 40263 Q值 [12.659195  2.475748]===> 步数 40263 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 182 / 最高得分 833
# 步数 40264 Q值 [12.618553   3.1611233]===> 步数 40264 / 本次行为 0 不跳 / 本次奖励 1 / Running   / 当前分数 183 / 最高得分 833
# 步数 40265 Q值 [11.831975   2.4785368]===> 步数 40265 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 183 / 最高得分 833
# 步数 40266 Q值 [11.90537    6.8343196]===> 步数 40266 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 183 / 最高得分 833
# 步数 40267 Q值 [11.815457 10.506807]===> 步数 40267 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 183 / 最高得分 833
# 步数 40268 Q值 [11.990617 11.446191]===> 步数 40268 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 183 / 最高得分 833
# 步数 40269 Q值 [11.879751 11.859758]===> 步数 40269 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 183 / 最高得分 833
# 步数 40270 Q值 [ 8.485604 11.996748]===> 步数 40270 / 本次行为 1 跳 / 本次奖励 0.1 / Running   / 当前分数 183 / 最高得分 833
# 步数 40271 Q值 [11.852692 11.407882]===> 步数 40271 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 183 / 最高得分 833
# 步数 40272 Q值 [11.923233 11.107819]===> 步数 40272 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 183 / 最高得分 833
# 步数 40273 Q值 [11.874479 10.330486]===> 步数 40273 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 183 / 最高得分 833
# 步数 40274 Q值 [11.961048  9.537495]===> 步数 40274 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 183 / 最高得分 833
# 步数 40275 Q值 [12.049003  7.022551]===> 步数 40275 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 183 / 最高得分 833
# 步数 40276 Q值 [12.068816   3.8999748]===> 步数 40276 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 183 / 最高得分 833
# 步数 40277 Q值 [11.979753   2.1793993]===> 步数 40277 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 183 / 最高得分 833
# 步数 40278 Q值 [11.950443   2.8932524]===> 步数 40278 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 183 / 最高得分 833
# 步数 40279 Q值 [12.010587   1.9431605]===> 步数 40279 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 183 / 最高得分 833
# 步数 40280 Q值 [12.062517   1.6358159]===> 步数 40280 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 183 / 最高得分 833
# 步数 40281 Q值 [12.181027   1.9430588]===> 步数 40281 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 183 / 最高得分 833
# 步数 40282 Q值 [12.150972   1.6279134]===> 步数 40282 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 183 / 最高得分 833
# 步数 40283 Q值 [12.208473   2.3361633]===> 步数 40283 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 183 / 最高得分 833
# 步数 40284 Q值 [12.279363   1.0736418]===> 步数 40284 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 183 / 最高得分 833
# 步数 40285 Q值 [12.302224   -0.47385937]===> 步数 40285 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 183 / 最高得分 833
# 步数 40286 Q值 [12.24657   -0.8777164]===> 步数 40286 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 183 / 最高得分 833
# 步数 40287 Q值 [12.147445  -1.5239977]===> 步数 40287 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 183 / 最高得分 833
# 步数 40288 Q值 [12.279675   -0.39677987]===> 步数 40288 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 183 / 最高得分 833
# 步数 40289 Q值 [12.346475   1.6038405]===> 步数 40289 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 183 / 最高得分 833
# 步数 40290 Q值 [12.427037  4.306332]===> 步数 40290 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 183 / 最高得分 833
# 步数 40291 Q值 [12.387312  7.830953]===> 步数 40291 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 183 / 最高得分 833
# 步数 40292 Q值 [12.410576 10.987099]===> 步数 40292 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 183 / 最高得分 833
# 步数 40293 Q值 [12.372273 11.997282]===> 步数 40293 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 183 / 最高得分 833
# 步数 40294 Q值 [ 9.797839  12.8058195]===> 步数 40294 / 本次行为 1 跳 / 本次奖励 0.1 / Running   / 当前分数 183 / 最高得分 833
# 步数 40295 Q值 [12.736182 11.928029]===> 步数 40295 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 183 / 最高得分 833
# 步数 40296 Q值 [12.735592 11.052766]===> 步数 40296 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 183 / 最高得分 833
# 步数 40297 Q值 [12.735579 10.387964]===> 步数 40297 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 183 / 最高得分 833
# 步数 40298 Q值 [12.71616   9.297071]===> 步数 40298 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 183 / 最高得分 833
# 步数 40299 Q值 [12.777542  6.927778]===> 步数 40299 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 183 / 最高得分 833
# 步数 40300 Q值 [12.754812   4.9921236]===> 步数 40300 / 本次行为 0 不跳 / 本次奖励 1 / Running   / 当前分数 184 / 最高得分 833
# 步数 40301 Q值 [11.859639   2.1050262]===> 步数 40301 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 184 / 最高得分 833
# 步数 40302 Q值 [11.895158   2.5307083]===> 步数 40302 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 184 / 最高得分 833
# 步数 40303 Q值 [11.99452    2.9184983]===> 步数 40303 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 184 / 最高得分 833
# 步数 40304 Q值 [12.121572   5.3122897]===> 步数 40304 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 184 / 最高得分 833
# 步数 40305 Q值 [12.009571   7.2639365]===> 步数 40305 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 184 / 最高得分 833
# 步数 40306 Q值 [11.98322   8.539035]===> 步数 40306 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 184 / 最高得分 833
# 步数 40307 Q值 [11.989886  9.918004]===> 步数 40307 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 184 / 最高得分 833
# 步数 40308 Q值 [11.964936 10.549   ]===> 步数 40308 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 184 / 最高得分 833
# 步数 40309 Q值 [11.992475  10.8585415]===> 步数 40309 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 184 / 最高得分 833
# 步数 40310 Q值 [11.890932 11.074883]===> 步数 40310 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 184 / 最高得分 833
# 步数 40311 Q值 [11.894536 11.130247]===> 步数 40311 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 184 / 最高得分 833
# 步数 40312 Q值 [11.993383 11.202329]===> 步数 40312 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 184 / 最高得分 833
# 步数 40313 Q值 [11.929868 10.481754]===> 步数 40313 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 184 / 最高得分 833
# 步数 40314 Q值 [11.972984 10.657604]===> 步数 40314 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 184 / 最高得分 833
# 步数 40315 Q值 [12.108011 10.896931]===> 步数 40315 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 184 / 最高得分 833
# 步数 40316 Q值 [12.04304  11.940266]===> 步数 40316 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 184 / 最高得分 833
# 步数 40317 Q值 [12.12508  12.015796]===> 步数 40317 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 184 / 最高得分 833
# 步数 40318 Q值 [11.971036 12.418852]===> 步数 40318 / 本次行为 1 跳 / 本次奖励 0.1 / Running   / 当前分数 184 / 最高得分 833
# 步数 40319 Q值 [12.252286 11.458809]===> 步数 40319 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 184 / 最高得分 833
# 步数 40320 Q值 [12.278353 11.447344]===> 步数 40320 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 184 / 最高得分 833
# 步数 40321 Q值 [12.337132 12.073721]===> 步数 40321 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 184 / 最高得分 833
# 步数 40322 Q值 [12.394369 11.674267]===> 步数 40322 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 184 / 最高得分 833
# 步数 40323 Q值 [12.329078 11.999348]===> 步数 40323 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 184 / 最高得分 833
# 步数 40324 Q值 [12.388062 12.002093]===> 步数 40324 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 184 / 最高得分 833
# 步数 40325 Q值 [12.4821005 11.958089 ]===> 步数 40325 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 184 / 最高得分 833
# 步数 40326 Q值 [12.450163 12.050342]===> 步数 40326 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 184 / 最高得分 833
# 步数 40327 Q值 [12.388579 11.48562 ]===> 步数 40327 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 184 / 最高得分 833
# 步数 40328 Q值 [12.494096 11.527195]===> 步数 40328 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 184 / 最高得分 833
# 步数 40329 Q值 [12.484083 11.660719]===> 步数 40329 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 184 / 最高得分 833
# 步数 40330 Q值 [12.271197 12.573414]===> 步数 40330 / 本次行为 1 跳 / 本次奖励 0.1 / Running   / 当前分数 184 / 最高得分 833
# 步数 40331 Q值 [12.559075 11.454061]===> 步数 40331 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 184 / 最高得分 833
# 步数 40332 Q值 [12.676872 11.05972 ]===> 步数 40332 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 184 / 最高得分 833
# 步数 40333 Q值 [12.761514 10.939502]===> 步数 40333 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 184 / 最高得分 833
# 步数 40334 Q值 [12.767164  9.839541]===> 步数 40334 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 184 / 最高得分 833
# 步数 40335 Q值 [12.710353  7.847903]===> 步数 40335 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 184 / 最高得分 833
# 步数 40336 Q值 [12.719905  5.270248]===> 步数 40336 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 184 / 最高得分 833
# 步数 40337 Q值 [12.692213   3.4887688]===> 步数 40337 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 184 / 最高得分 833
# 步数 40338 Q值 [12.694973   2.7314374]===> 步数 40338 / 本次行为 0 不跳 / 本次奖励 1 / Running   / 当前分数 185 / 最高得分 833
# 步数 40339 Q值 [11.877889  1.259443]===> 步数 40339 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 185 / 最高得分 833
# 步数 40340 Q值 [11.898085   2.3894618]===> 步数 40340 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 185 / 最高得分 833
# 步数 40341 Q值 [12.0152025  3.6697388]===> 步数 40341 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 185 / 最高得分 833
# 步数 40342 Q值 [11.97686    5.4451113]===> 步数 40342 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 185 / 最高得分 833
# 步数 40343 Q值 [12.02365   8.734597]===> 步数 40343 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 185 / 最高得分 833
# 步数 40344 Q值 [12.018774 10.383443]===> 步数 40344 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 185 / 最高得分 833
# 步数 40345 Q值 [12.0495205 11.29239  ]===> 步数 40345 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 185 / 最高得分 833
# 步数 40346 Q值 [12.027215 11.179103]===> 步数 40346 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 185 / 最高得分 833
# 步数 40347 Q值 [12.114545 11.826904]===> 步数 40347 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 185 / 最高得分 833
# 步数 40348 Q值 [12.028103 11.928195]===> 步数 40348 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 185 / 最高得分 833
# 步数 40349 Q值 [12.066991 11.954977]===> 步数 40349 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 185 / 最高得分 833
# 步数 40350 Q值 [12.158621 11.584984]===> 步数 40350 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 185 / 最高得分 833
# 步数 40351 Q值 [12.109594 12.293971]===> 步数 40351 / 本次行为 1 跳 / 本次奖励 0.1 / Running   / 当前分数 185 / 最高得分 833
# 步数 40352 Q值 [12.219119 11.852603]===> 步数 40352 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 185 / 最高得分 833
# 步数 40353 Q值 [12.188801 11.540427]===> 步数 40353 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 185 / 最高得分 833
# 步数 40354 Q值 [12.201296 11.433292]===> 步数 40354 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 185 / 最高得分 833
# 步数 40355 Q值 [12.289169 11.726673]===> 步数 40355 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 185 / 最高得分 833
# 步数 40356 Q值 [12.382907 11.722632]===> 步数 40356 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 185 / 最高得分 833
# 步数 40357 Q值 [12.392141 11.829105]===> 步数 40357 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 185 / 最高得分 833
# 步数 40358 Q值 [12.352254 11.623292]===> 步数 40358 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 185 / 最高得分 833
# 步数 40359 Q值 [12.322712 11.530751]===> 步数 40359 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 185 / 最高得分 833
# 步数 40360 Q值 [12.399836 11.900986]===> 步数 40360 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 185 / 最高得分 833
# 步数 40361 Q值 [12.382821 11.797934]===> 步数 40361 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 185 / 最高得分 833
# 步数 40362 Q值 [12.450354 12.064969]===> 步数 40362 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 185 / 最高得分 833
# 步数 40363 Q值 [12.497754 12.480563]===> 步数 40363 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 185 / 最高得分 833
# 步数 40364 Q值 [12.395456 12.930403]===> 步数 40364 / 本次行为 1 跳 / 本次奖励 0.1 / Running   / 当前分数 185 / 最高得分 833
# 步数 40365 Q值 [12.543991 11.404817]===> 步数 40365 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 185 / 最高得分 833
# 步数 40366 Q值 [12.380264 10.83883 ]===> 步数 40366 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 185 / 最高得分 833
# 步数 40367 Q值 [12.473025 10.03041 ]===> 步数 40367 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 185 / 最高得分 833
# 步数 40368 Q值 [12.598903  7.994783]===> 步数 40368 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 185 / 最高得分 833
# 步数 40369 Q值 [12.6267395  6.5391116]===> 步数 40369 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 185 / 最高得分 833
# 步数 40370 Q值 [12.537804  4.748967]===> 步数 40370 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 185 / 最高得分 833
# 步数 40371 Q值 [12.464111   3.9088073]===> 步数 40371 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 185 / 最高得分 833
# 步数 40372 Q值 [12.562501  4.59936 ]===> 步数 40372 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 185 / 最高得分 833
# 步数 40373 Q值 [12.594189  5.66537 ]===> 步数 40373 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 185 / 最高得分 833
# 步数 40374 Q值 [12.579193   5.8650017]===> 步数 40374 / 本次行为 0 不跳 / 本次奖励 1 / Running   / 当前分数 186 / 最高得分 833
# 步数 40375 Q值 [11.698381   4.8413067]===> 步数 40375 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 186 / 最高得分 833
# 步数 40376 Q值 [11.70964   5.645396]===> 步数 40376 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 186 / 最高得分 833
# 步数 40377 Q值 [11.778703   7.8219843]===> 步数 40377 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 186 / 最高得分 833
# 步数 40378 Q值 [11.847131  9.657193]===> 步数 40378 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 186 / 最高得分 833
# 步数 40379 Q值 [11.815478 11.044529]===> 步数 40379 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 186 / 最高得分 833
# 步数 40380 Q值 [11.898981 11.501288]===> 步数 40380 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 186 / 最高得分 833
# 步数 40381 Q值 [11.898693 11.691994]===> 步数 40381 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 186 / 最高得分 833
# 步数 40382 Q值 [11.814956 11.997714]===> 步数 40382 / 本次行为 1 跳 / 本次奖励 0.1 / Running   / 当前分数 186 / 最高得分 833
# 步数 40383 Q值 [11.869648 11.900393]===> 步数 40383 / 本次行为 1 跳 / 本次奖励 0.1 / Running   / 当前分数 186 / 最高得分 833
# 步数 40384 Q值 [11.870594 11.08434 ]===> 步数 40384 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 186 / 最高得分 833
# 步数 40385 Q值 [11.882333 10.788206]===> 步数 40385 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 186 / 最高得分 833
# 步数 40386 Q值 [11.898399 10.121345]===> 步数 40386 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 186 / 最高得分 833
# 步数 40387 Q值 [11.958509  9.619608]===> 步数 40387 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 186 / 最高得分 833
# 步数 40388 Q值 [11.950312  8.692976]===> 步数 40388 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 186 / 最高得分 833
# 步数 40389 Q值 [11.97786    7.4747677]===> 步数 40389 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 186 / 最高得分 833
# 步数 40390 Q值 [12.018572   5.7151475]===> 步数 40390 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 186 / 最高得分 833
# 步数 40391 Q值 [12.01988    4.6817274]===> 步数 40391 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 186 / 最高得分 833
# 步数 40392 Q值 [11.979562   3.5841389]===> 步数 40392 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 186 / 最高得分 833
# 步数 40393 Q值 [11.9772835  2.9701602]===> 步数 40393 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 186 / 最高得分 833
# 步数 40394 Q值 [12.03466    2.1110191]===> 步数 40394 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 186 / 最高得分 833
# 步数 40395 Q值 [12.022733   2.8350186]===> 步数 40395 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 186 / 最高得分 833
# 步数 40396 Q值 [12.030748   3.1846526]===> 步数 40396 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 186 / 最高得分 833
# 步数 40397 Q值 [12.05957  4.07615]===> 步数 40397 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 186 / 最高得分 833
# 步数 40398 Q值 [12.097775  6.05155 ]===> 步数 40398 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 186 / 最高得分 833
# 步数 40399 Q值 [12.066631  7.186202]===> 步数 40399 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 186 / 最高得分 833
# 步数 40400 Q值 [12.2036915  9.575103 ]===> 步数 40400 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 186 / 最高得分 833
# 步数 40401 Q值 [10.749769 12.107744]===> 步数 40401 / 本次行为 1 跳 / 本次奖励 0.1 / Running   / 当前分数 186 / 最高得分 833
# 步数 40402 Q值 [12.126281 10.811309]===> 步数 40402 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 186 / 最高得分 833
# 步数 40403 Q值 [12.275812   9.5639925]===> 步数 40403 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 186 / 最高得分 833
# 步数 40404 Q值 [12.476777   7.5124907]===> 步数 40404 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 186 / 最高得分 833
# 步数 40405 Q值 [12.456559   3.8960187]===> 步数 40405 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 186 / 最高得分 833
# 步数 40406 Q值 [12.6031685  3.530755 ]===> 步数 40406 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 186 / 最高得分 833
# 步数 40407 Q值 [12.530547   2.4910312]===> 步数 40407 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 186 / 最高得分 833
# 步数 40408 Q值 [12.556648  1.661062]===> 步数 40408 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 186 / 最高得分 833
# 步数 40409 Q值 [12.559354   1.2201424]===> 步数 40409 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 186 / 最高得分 833
# 步数 40410 Q值 [12.50216    2.0143123]===> 步数 40410 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 186 / 最高得分 833
# 步数 40411 Q值 [12.552895   3.2604208]===> 步数 40411 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 186 / 最高得分 833
# 步数 40412 Q值 [12.552007  2.920167]===> 步数 40412 / 本次行为 0 不跳 / 本次奖励 1 / Running   / 当前分数 187 / 最高得分 833
# 步数 40413 Q值 [11.692925   2.2780888]===> 步数 40413 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 187 / 最高得分 833
# 步数 40414 Q值 [11.699016   3.0860884]===> 步数 40414 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 187 / 最高得分 833
# 步数 40415 Q值 [11.804377  6.370378]===> 步数 40415 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 187 / 最高得分 833
# 步数 40416 Q值 [11.852333  8.183286]===> 步数 40416 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 187 / 最高得分 833
# 步数 40417 Q值 [11.928654  9.984876]===> 步数 40417 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 187 / 最高得分 833
# 步数 40418 Q值 [11.971431 10.933908]===> 步数 40418 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 187 / 最高得分 833
# 步数 40419 Q值 [11.84702 11.10475]===> 步数 40419 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 187 / 最高得分 833
# 步数 40420 Q值 [11.768415 11.518075]===> 步数 40420 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 187 / 最高得分 833
# 步数 40421 Q值 [10.705622 11.950733]===> 步数 40421 / 本次行为 1 跳 / 本次奖励 0.1 / Running   / 当前分数 187 / 最高得分 833
# 步数 40422 Q值 [11.847026 11.9612  ]===> 步数 40422 / 本次行为 1 跳 / 本次奖励 0.1 / Running   / 当前分数 187 / 最高得分 833
# 步数 40423 Q值 [11.925626 10.464359]===> 步数 40423 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 187 / 最高得分 833
# 步数 40424 Q值 [11.964256  9.531954]===> 步数 40424 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 187 / 最高得分 833
# 步数 40425 Q值 [11.983778  7.759905]===> 步数 40425 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 187 / 最高得分 833
# 步数 40426 Q值 [11.964818   6.2332606]===> 步数 40426 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 187 / 最高得分 833
# 步数 40427 Q值 [11.982879  4.838696]===> 步数 40427 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 187 / 最高得分 833
# 步数 40428 Q值 [11.989252  3.390417]===> 步数 40428 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 187 / 最高得分 833
# 步数 40429 Q值 [11.993983   2.6079214]===> 步数 40429 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 187 / 最高得分 833
# 步数 40430 Q值 [11.915974  1.515561]===> 步数 40430 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 187 / 最高得分 833
# 步数 40431 Q值 [12.006125   1.5244305]===> 步数 40431 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 187 / 最高得分 833
# 步数 40432 Q值 [11.976812   0.1603346]===> 步数 40432 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 187 / 最高得分 833
# 步数 40433 Q值 [11.852898   0.3855578]===> 步数 40433 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 187 / 最高得分 833
# 步数 40434 Q值 [11.926167   0.2606787]===> 步数 40434 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 187 / 最高得分 833
# 步数 40435 Q值 [12.117258    0.63313997]===> 步数 40435 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 187 / 最高得分 833
# 步数 40436 Q值 [12.120623    0.43117467]===> 步数 40436 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 187 / 最高得分 833
# 步数 40437 Q值 [12.220105   1.6905026]===> 步数 40437 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 187 / 最高得分 833
# 步数 40438 Q值 [12.288871   1.8744961]===> 步数 40438 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 187 / 最高得分 833
# 步数 40439 Q值 [12.240372   4.1309633]===> 步数 40439 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 187 / 最高得分 833
# 步数 40440 Q值 [12.31628   7.807882]===> 步数 40440 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 187 / 最高得分 833
# 步数 40441 Q值 [12.169648 10.868834]===> 步数 40441 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 187 / 最高得分 833
# 步数 40442 Q值 [11.03592  12.302397]===> 步数 40442 / 本次行为 1 跳 / 本次奖励 0.1 / Running   / 当前分数 187 / 最高得分 833
# 步数 40443 Q值 [12.533058 11.011378]===> 步数 40443 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 187 / 最高得分 833
# 步数 40444 Q值 [12.464163 10.010332]===> 步数 40444 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 187 / 最高得分 833
# 步数 40445 Q值 [12.65216    7.1647224]===> 步数 40445 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 187 / 最高得分 833
# 步数 40446 Q值 [12.609691  7.362347]===> 步数 40446 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 187 / 最高得分 833
# 步数 40447 Q值 [12.685731   4.8022776]===> 步数 40447 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 187 / 最高得分 833
# 步数 40448 Q值 [12.664639   2.1228416]===> 步数 40448 / 本次行为 0 不跳 / 本次奖励 1 / Running   / 当前分数 188 / 最高得分 833
# 步数 40449 Q值 [11.752971   1.6445445]===> 步数 40449 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 188 / 最高得分 833
# 步数 40450 Q值 [11.813316   1.7225683]===> 步数 40450 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 188 / 最高得分 833
# 步数 40451 Q值 [11.833504   3.3898363]===> 步数 40451 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 188 / 最高得分 833
# 步数 40452 Q值 [11.853075  4.207307]===> 步数 40452 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 188 / 最高得分 833
# 步数 40453 Q值 [11.870671   5.4863224]===> 步数 40453 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 188 / 最高得分 833
# 步数 40454 Q值 [11.7945595  6.787114 ]===> 步数 40454 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 188 / 最高得分 833
# 步数 40455 Q值 [11.833618  7.935737]===> 步数 40455 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 188 / 最高得分 833
# 步数 40456 Q值 [11.757407  9.867633]===> 步数 40456 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 188 / 最高得分 833
# 步数 40457 Q值 [11.803306 10.598042]===> 步数 40457 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 188 / 最高得分 833
# 步数 40458 Q值 [11.881444 10.954488]===> 步数 40458 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 188 / 最高得分 833
# ...
# 步数 45883 Q值 [12.520406  7.542821]===> 步数 45883 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 334 / 最高得分 833
# 步数 45884 Q值 [12.488127  7.544468]===> 步数 45884 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 334 / 最高得分 833
# 步数 45885 Q值 [12.522773  7.739805]===> 步数 45885 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 334 / 最高得分 833
# 步数 45886 Q值 [12.55385  10.157749]===> 步数 45886 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 334 / 最高得分 833
# 步数 45887 Q值 [12.578586 10.64851 ]===> 步数 45887 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 334 / 最高得分 833
# 步数 45888 Q值 [12.565287 11.126944]===> 步数 45888 / 本次行为 0 不跳 / 本次奖励 1 / Running   / 当前分数 335 / 最高得分 833
# 步数 45889 Q值 [11.779534 11.159042]===> 步数 45889 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 335 / 最高得分 833
# 步数 45890 Q值 [11.240351 11.703236]===> 步数 45890 / 本次行为 1 跳 / 本次奖励 0.1 / Running   / 当前分数 335 / 最高得分 833
# 步数 45891 Q值 [11.72735   10.8046255]===> 步数 45891 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 335 / 最高得分 833
# 步数 45892 Q值 [11.749204 10.710146]===> 步数 45892 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 335 / 最高得分 833
# 步数 45893 Q值 [11.860675  10.2534075]===> 步数 45893 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 335 / 最高得分 833
# 步数 45894 Q值 [11.928624  9.983673]===> 步数 45894 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 335 / 最高得分 833
# 步数 45895 Q值 [11.94055    9.5444355]===> 步数 45895 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 335 / 最高得分 833
# 步数 45896 Q值 [11.887302  9.166063]===> 步数 45896 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 335 / 最高得分 833
# 步数 45897 Q值 [11.915825  9.163688]===> 步数 45897 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 335 / 最高得分 833
# 步数 45898 Q值 [11.977736  9.789661]===> 步数 45898 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 335 / 最高得分 833
# 步数 45899 Q值 [11.888913  8.395767]===> 步数 45899 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 335 / 最高得分 833
# 步数 45900 Q值 [12.043103  6.114137]===> 步数 45900 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 335 / 最高得分 833
# 步数 45901 Q值 [11.963319  6.343108]===> 步数 45901 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 335 / 最高得分 833
# 步数 45902 Q值 [11.970657   6.1477327]===> 步数 45902 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 335 / 最高得分 833
# 步数 45903 Q值 [11.964358  5.760963]===> 步数 45903 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 335 / 最高得分 833
# 步数 45904 Q值 [12.02846    5.0071173]===> 步数 45904 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 335 / 最高得分 833
# 步数 45905 Q值 [12.09734    4.1960664]===> 步数 45905 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 335 / 最高得分 833
# 步数 45906 Q值 [12.075537   4.6095915]===> 步数 45906 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 335 / 最高得分 833
# 步数 45907 Q值 [12.099284   6.9550705]===> 步数 45907 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 335 / 最高得分 833
# 步数 45908 Q值 [12.153106  7.752681]===> 步数 45908 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 335 / 最高得分 833
# 步数 45909 Q值 [12.098126 10.272329]===> 步数 45909 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 335 / 最高得分 833
# 步数 45910 Q值 [12.118621 11.958566]===> 步数 45910 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 335 / 最高得分 833
# 步数 45911 Q值 [11.451256 12.487959]===> 步数 45911 / 本次行为 1 跳 / 本次奖励 0.1 / Running   / 当前分数 335 / 最高得分 833
# 步数 45912 Q值 [12.403832 12.181701]===> 步数 45912 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 335 / 最高得分 833
# 步数 45913 Q值 [12.491928 12.4891  ]===> 步数 45913 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 335 / 最高得分 833
# 步数 45914 Q值 [12.430111  11.1758795]===> 步数 45914 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 335 / 最高得分 833
# 步数 45915 Q值 [12.466985 10.785539]===> 步数 45915 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 335 / 最高得分 833
# 步数 45916 Q值 [12.5236435 10.203239 ]===> 步数 45916 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 335 / 最高得分 833
# 步数 45917 Q值 [12.461439  9.555294]===> 步数 45917 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 335 / 最高得分 833
# 步数 45918 Q值 [12.520318  8.082083]===> 步数 45918 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 335 / 最高得分 833
# 步数 45919 Q值 [12.520015   6.5574493]===> 步数 45919 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 335 / 最高得分 833
# 步数 45920 Q值 [12.549417   6.5345674]===> 步数 45920 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 335 / 最高得分 833
# 步数 45921 Q值 [12.565119   5.7221656]===> 步数 45921 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 335 / 最高得分 833
# 步数 45922 Q值 [12.519114   5.6239676]===> 步数 45922 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 335 / 最高得分 833
# 步数 45923 Q值 [12.618084  7.320137]===> 步数 45923 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 335 / 最高得分 833
# 步数 45924 Q值 [12.519455 10.010343]===> 步数 45924 / 本次行为 0 不跳 / 本次奖励 1 / Running   / 当前分数 336 / 最高得分 833
# 步数 45925 Q值 [11.742476 10.042227]===> 步数 45925 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 336 / 最高得分 833
# 步数 45926 Q值 [11.628581 11.216597]===> 步数 45926 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 336 / 最高得分 833
# 步数 45927 Q值 [11.644652 11.395063]===> 步数 45927 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 336 / 最高得分 833
# 步数 45928 Q值 [10.932741 11.892111]===> 步数 45928 / 本次行为 1 跳 / 本次奖励 0.1 / Running   / 当前分数 336 / 最高得分 833
# 步数 45929 Q值 [11.777143 11.342442]===> 步数 45929 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 336 / 最高得分 833
# 步数 45930 Q值 [11.727283 10.905889]===> 步数 45930 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 336 / 最高得分 833
# 步数 45931 Q值 [11.802813 10.795731]===> 步数 45931 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 336 / 最高得分 833
# 步数 45932 Q值 [11.67385  10.555513]===> 步数 45932 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 336 / 最高得分 833
# 步数 45933 Q值 [11.634876  9.950309]===> 步数 45933 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 336 / 最高得分 833
# 步数 45934 Q值 [11.731562  9.533551]===> 步数 45934 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 336 / 最高得分 833
# 步数 45935 Q值 [11.77416   9.671736]===> 步数 45935 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 336 / 最高得分 833
# 步数 45936 Q值 [11.8197565  9.554229 ]===> 步数 45936 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 336 / 最高得分 833
# 步数 45937 Q值 [11.849363  9.377086]===> 步数 45937 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 336 / 最高得分 833
# 步数 45938 Q值 [11.904022  9.558154]===> 步数 45938 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 336 / 最高得分 833
# 步数 45939 Q值 [11.980333  9.108424]===> 步数 45939 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 336 / 最高得分 833
# 步数 45940 Q值 [12.030175  8.783142]===> 步数 45940 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 336 / 最高得分 833
# 步数 45941 Q值 [12.005144   7.3259683]===> 步数 45941 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 336 / 最高得分 833
# 步数 45942 Q值 [12.073928   7.7202945]===> 步数 45942 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 336 / 最高得分 833
# 步数 45943 Q值 [12.153744  7.72529 ]===> 步数 45943 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 336 / 最高得分 833
# 步数 45944 Q值 [12.190375  9.447676]===> 步数 45944 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 336 / 最高得分 833
# 步数 45945 Q值 [12.134638 10.841828]===> 步数 45945 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 336 / 最高得分 833
# 步数 45946 Q值 [12.1166935 12.0054865]===> 步数 45946 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 336 / 最高得分 833
# 步数 45947 Q值 [11.401046 12.341553]===> 步数 45947 / 本次行为 1 跳 / 本次奖励 0.1 / Running   / 当前分数 336 / 最高得分 833
# 步数 45948 Q值 [12.1004305 11.677632 ]===> 步数 45948 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 336 / 最高得分 833
# 步数 45949 Q值 [12.196266 11.58203 ]===> 步数 45949 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 336 / 最高得分 833
# 步数 45950 Q值 [12.2718525 11.147546 ]===> 步数 45950 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 336 / 最高得分 833
# 步数 45951 Q值 [12.306218 11.077995]===> 步数 45951 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 336 / 最高得分 833
# 步数 45952 Q值 [12.449067 10.250293]===> 步数 45952 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 336 / 最高得分 833
# 步数 45953 Q值 [12.464035  8.230823]===> 步数 45953 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 336 / 最高得分 833
# 步数 45954 Q值 [12.531216   7.9271107]===> 步数 45954 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 336 / 最高得分 833
# 步数 45955 Q值 [12.485123   7.1285253]===> 步数 45955 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 336 / 最高得分 833
# 步数 45956 Q值 [12.563488  6.503868]===> 步数 45956 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 336 / 最高得分 833
# 步数 45957 Q值 [12.642038   6.2591424]===> 步数 45957 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 336 / 最高得分 833
# 步数 45958 Q值 [12.685339   6.0555706]===> 步数 45958 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 336 / 最高得分 833
# 步数 45959 Q值 [12.629187  6.151454]===> 步数 45959 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 336 / 最高得分 833
# 步数 45960 Q值 [12.589387  9.069073]===> 步数 45960 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 336 / 最高得分 833
# 步数 45961 Q值 [12.59066  10.462226]===> 步数 45961 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 336 / 最高得分 833
# 步数 45962 Q值 [12.585108 10.598047]===> 步数 45962 / 本次行为 0 不跳 / 本次奖励 1 / Running   / 当前分数 337 / 最高得分 833
# 步数 45963 Q值 [11.7363   10.613341]===> 步数 45963 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 337 / 最高得分 833
# 步数 45964 Q值 [ 8.402863 11.842583]===> 步数 45964 / 本次行为 1 跳 / 本次奖励 0.1 / Running   / 当前分数 337 / 最高得分 833
# 步数 45965 Q值 [11.861232 10.751615]===> 步数 45965 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 337 / 最高得分 833
# 步数 45966 Q值 [11.886954 10.927776]===> 步数 45966 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 337 / 最高得分 833
# 步数 45967 Q值 [11.87064 10.76586]===> 步数 45967 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 337 / 最高得分 833
# 步数 45968 Q值 [11.891903 10.376275]===> 步数 45968 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 337 / 最高得分 833
# 步数 45969 Q值 [11.971997  9.681026]===> 步数 45969 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 337 / 最高得分 833
# 步数 45970 Q值 [11.939157   7.5755935]===> 步数 45970 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 337 / 最高得分 833
# 步数 45971 Q值 [11.941773   5.8697543]===> 步数 45971 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 337 / 最高得分 833
# 步数 45972 Q值 [11.893715  5.225476]===> 步数 45972 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 337 / 最高得分 833
# 步数 45973 Q值 [11.8540125  2.3259904]===> 步数 45973 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 337 / 最高得分 833
# 步数 45974 Q值 [11.962268   1.1443088]===> 步数 45974 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 337 / 最高得分 833
# 步数 45975 Q值 [12.002975    0.96892345]===> 步数 45975 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 337 / 最高得分 833
# 步数 45976 Q值 [12.050339   1.7152897]===> 步数 45976 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 337 / 最高得分 833
# 步数 45977 Q值 [12.0116825  1.4036165]===> 步数 45977 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 337 / 最高得分 833
# 步数 45978 Q值 [12.054156   0.7843192]===> 步数 45978 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 337 / 最高得分 833
# 步数 45979 Q值 [12.049924   1.0510652]===> 步数 45979 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 337 / 最高得分 833
# 步数 45980 Q值 [12.18354     0.72931296]===> 步数 45980 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 337 / 最高得分 833
# 步数 45981 Q值 [12.168242   -0.45414534]===> 步数 45981 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 337 / 最高得分 833
# 步数 45982 Q值 [12.1411915 -0.7419034]===> 步数 45982 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 337 / 最高得分 833
# 步数 45983 Q值 [12.135838    0.63766575]===> 步数 45983 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 337 / 最高得分 833
# 步数 45984 Q值 [12.088877   3.3059793]===> 步数 45984 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 337 / 最高得分 833
# 步数 45985 Q值 [12.095298   4.9497595]===> 步数 45985 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 337 / 最高得分 833
# 步数 45986 Q值 [12.249539  8.400945]===> 步数 45986 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 337 / 最高得分 833
# 步数 45987 Q值 [12.157309 10.318384]===> 步数 45987 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 337 / 最高得分 833
# 步数 45988 Q值 [12.236549 11.701719]===> 步数 45988 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 337 / 最高得分 833
# 步数 45989 Q值 [11.684208 12.28101 ]===> 步数 45989 / 本次行为 1 跳 / 本次奖励 0.1 / Running   / 当前分数 337 / 最高得分 833
# 步数 45990 Q值 [12.438328 11.628897]===> 步数 45990 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 337 / 最高得分 833
# 步数 45991 Q值 [12.473637 10.853961]===> 步数 45991 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 337 / 最高得分 833
# 步数 45992 Q值 [12.644778 10.253274]===> 步数 45992 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 337 / 最高得分 833
# 步数 45993 Q值 [12.78144   9.155456]===> 步数 45993 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 337 / 最高得分 833
# 步数 45994 Q值 [12.789016  8.125567]===> 步数 45994 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 337 / 最高得分 833
# 步数 45995 Q值 [12.753433  5.767569]===> 步数 45995 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 337 / 最高得分 833
# 步数 45996 Q值 [12.68424   3.757394]===> 步数 45996 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 337 / 最高得分 833
# 步数 45997 Q值 [12.685176   2.5487123]===> 步数 45997 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 337 / 最高得分 833
# 步数 45998 Q值 [12.571403   2.7117553]===> 步数 45998 / 本次行为 0 不跳 / 本次奖励 1 / Running   / 当前分数 338 / 最高得分 833
# 步数 45999 Q值 [11.755869   0.9906342]===> 步数 45999 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 338 / 最高得分 833
# 步数 46000 Q值 [11.754974   1.8395722]===> 步数 46000 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 338 / 最高得分 833
# 步数 46001 Q值 [11.8829155  4.089621 ]===> 步数 46001 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 338 / 最高得分 833
# 步数 46002 Q值 [11.959439   6.9076815]===> 步数 46002 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 338 / 最高得分 833
# 步数 46003 Q值 [11.979822  9.852709]===> 步数 46003 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 338 / 最高得分 833
# 步数 46004 Q值 [11.879393 10.695712]===> 步数 46004 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 338 / 最高得分 833
# 步数 46005 Q值 [11.953772 11.288476]===> 步数 46005 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 338 / 最高得分 833
# 步数 46006 Q值 [11.978624 11.505219]===> 步数 46006 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 338 / 最高得分 833
# 步数 46007 Q值 [11.958334 11.991972]===> 步数 46007 / 本次行为 1 跳 / 本次奖励 0.1 / Running   / 当前分数 338 / 最高得分 833
# 步数 46008 Q值 [11.918972 10.813843]===> 步数 46008 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 338 / 最高得分 833
# 步数 46009 Q值 [11.945851 11.080733]===> 步数 46009 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 338 / 最高得分 833
# 步数 46010 Q值 [11.908728 10.749802]===> 步数 46010 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 338 / 最高得分 833
# 步数 46011 Q值 [12.025562 10.618014]===> 步数 46011 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 338 / 最高得分 833
# 步数 46012 Q值 [12.007371 10.094902]===> 步数 46012 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 338 / 最高得分 833
# 步数 46013 Q值 [12.118481  8.704501]===> 步数 46013 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 338 / 最高得分 833
# 步数 46014 Q值 [12.12924    7.6939535]===> 步数 46014 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 338 / 最高得分 833
# 步数 46015 Q值 [12.244835   5.6819425]===> 步数 46015 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 338 / 最高得分 833
# 步数 46016 Q值 [12.27126    4.4185843]===> 步数 46016 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 338 / 最高得分 833
# 步数 46017 Q值 [12.186519   4.1013594]===> 步数 46017 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 338 / 最高得分 833
# 步数 46018 Q值 [12.184804  3.32507 ]===> 步数 46018 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 338 / 最高得分 833
# 步数 46019 Q值 [12.136576   5.0355377]===> 步数 46019 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 338 / 最高得分 833
# 步数 46020 Q值 [12.120267   5.1785846]===> 步数 46020 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 338 / 最高得分 833
# 步数 46021 Q值 [12.118374  6.342189]===> 步数 46021 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 338 / 最高得分 833
# 步数 46022 Q值 [12.187645  8.105449]===> 步数 46022 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 338 / 最高得分 833
# 步数 46023 Q值 [12.214173  9.472959]===> 步数 46023 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 338 / 最高得分 833
# 步数 46024 Q值 [12.297551 10.729159]===> 步数 46024 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 338 / 最高得分 833
# 步数 46025 Q值 [11.687665 11.845962]===> 步数 46025 / 本次行为 1 跳 / 本次奖励 0.1 / Running   / 当前分数 338 / 最高得分 833
# 步数 46026 Q值 [12.352254  9.762499]===> 步数 46026 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 338 / 最高得分 833
# 步数 46027 Q值 [11.543011  8.380677]===> 步数 46027 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 338 / 最高得分 833
# 步数 46028 Q值 [11.960055  6.532564]===> 步数 46028 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 338 / 最高得分 833
# 步数 46029 Q值 [12.380822  3.527377]===> 步数 46029 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 338 / 最高得分 833
# 步数 46030 Q值 [12.524501   2.6933005]===> 步数 46030 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 338 / 最高得分 833
# 步数 46031 Q值 [12.578634   1.5166842]===> 步数 46031 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 338 / 最高得分 833
# 步数 46032 Q值 [12.627498   1.5852396]===> 步数 46032 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 338 / 最高得分 833
# 步数 46033 Q值 [12.676301  2.182836]===> 步数 46033 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 338 / 最高得分 833
# 步数 46034 Q值 [12.722462   1.2548281]===> 步数 46034 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 338 / 最高得分 833
# 步数 46035 Q值 [12.745307   1.7178755]
