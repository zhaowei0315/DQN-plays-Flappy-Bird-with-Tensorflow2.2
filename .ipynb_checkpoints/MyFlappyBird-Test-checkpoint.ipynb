# %%
import random
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
from collections import deque
import sys
import cv2
import os

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, Sequential, optimizers, losses, datasets, metrics, callbacks, models

plt.rcParams['font.family'] = ['SimSun']
plt.rcParams['axes.unicode_minus'] = False

sys.path.append(os.path.join('game'))

# print('Headless Mode')
# os.environ["SDL_VIDEODRIVER"] = "dummy"

from IPython.display import clear_output

print(tf.__version__)
# Out:
# 2.4.1

# %% [markdown]
# # 定义参数

# %%
ACTIONS = 2 # number of valid actions

# 模型存放文件夹路径
MODEL_FOLDER = os.path.join("FlappyBird_Model")
MODEL_DIR = os.path.join(MODEL_FOLDER, "FlappyBird_Model.h5")
MODEL_DIR
# Out:
# 'FlappyBird_Model\\FlappyBird_Model.h5'

# %% [markdown]
# # 将游戏返回的图片转为80*80的灰阶图片
# 调整大小 => 灰度化 => 二值化 => 4帧叠加

# %%
# preprocess raw image to 80*80 gray image
def preprocess(observation):
    observation = cv2.cvtColor(cv2.resize(observation, (80, 80)), cv2.COLOR_BGR2GRAY)
    ret, observation = cv2.threshold(observation, 1, 255, cv2.THRESH_BINARY)
    return np.reshape(observation,(80,80,1))

# %% [markdown]
# # 加载模型

# %%
def load_model():
    print('加载模型')
    return models.load_model(MODEL_DIR)

# %% [markdown]
# # 获得下一个Action

# %%
def getAction(model, state, timeStep):
    state_ = tf.expand_dims(state, axis=0)  # 扩展维度 (80,80,4) => (1,80,80,4)
    QValue = model(state_)[0]
    print("步数", timeStep, 'Q值', QValue.numpy(), end='')

    action = np.zeros(ACTIONS)  # 生成[0, 0]初始action
    action_index = 0

    # 按照Q表采取Action
    action_index = np.argmax(QValue)
    action[action_index] = 1

    return action, action_index

# %% [markdown]
# # 打印日志

# %%
def print_info(timeStep, action_index, reward, terminal, score, highest_record):
    action_text = ''
    if action_index == 0:
        action_text = '不跳'
    else:
        action_text = '跳'
    if terminal:
        print("===> 步数", timeStep, "/ 本次行为", action_index, action_text, "/ 本次奖励", reward, "/ Game Over", "/ 累计分数", score, '/ 最高得分', highest_record)
#         sys.__stdout__.write("===> 步数"+str(timeStep)+"/ 本次行为"+str(action_index)+"/ 本次奖励"+str(reward)+"/ Game Over"+"/ 累计分数"+str(score)+ '/ 最高得分'+str(highest_record))
    else:
        print("===> 步数", timeStep, "/ 本次行为", action_index, action_text, "/ 本次奖励", reward, "/ Running  ", "/ 当前分数", score, '/ 最高得分', highest_record)
#         sys.__stdout__.write("===> 步数"+str(timeStep)+"/ 本次行为"+str(action_index)+"/ 本次奖励"+str(reward)+"/ Running  "+"/ 当前分数"+str(score)+ '/ 最高得分'+str(highest_record))

# %% [markdown]
# # 主流程

# %%
import wrapped_flappy_bird as game

flappyBird = game.GameState()

timeStep = 0 
total_reward = 0
highest_record = 0

# 载入模型
model = load_model()

# 第一次与智能体交互
action = np.array([1, 0])# do nothing
observation0, reward, terminal = flappyBird.frame_step(action)

# 展示第一张图片
plt.imshow(np.rot90(np.rot90(np.rot90(observation0))))
plt.gca().invert_xaxis()
plt.title('The First Picture')
plt.show()

# 处理第一张图片
observation0 = cv2.cvtColor(cv2.resize(observation0, (80, 80)), cv2.COLOR_BGR2GRAY)
ret, observation0 = cv2.threshold(observation0, 1, 255, cv2.THRESH_BINARY)

# 展示第一张图片
plt.imshow(np.rot90(np.rot90(np.rot90(observation0))))
plt.gca().invert_xaxis()
plt.title('The First Picture')
plt.show()

# 第一次的4张图片都是一样的
currentObservation = np.stack((observation0, observation0, observation0, observation0), axis = 2)

while True:
    # 根据上一次的Observation，获得下一次的Action
    action, action_index = getAction(model, currentObservation, timeStep)
    
    # 将Action传入游戏，获得游戏的反馈(状态，奖励，是否GameOver，生效的行为)
    nextObservation, reward, terminal = flappyBird.frame_step(action)

    # 处理图片
    nextObservation = preprocess(nextObservation)
    
    # 将最近的图片后面追加老的前3张图片，从而得到一个新状态
    newObservation = np.append(nextObservation, currentObservation[:,:,:3], axis = 2)
        
    # 计算得分
    if terminal:
        total_reward = 0# Game Over 得分清零
    elif reward == 1:
        total_reward += reward
        
    if highest_record < total_reward:
        highest_record = total_reward

    # 更替状态
    currentObservation = newObservation
    
    # 打印日志
    if timeStep % 1 == 0:
        print_info(timeStep, action_index, reward, terminal, total_reward, highest_record)
        
    # 每第1000次，打印一次图片
    if timeStep % 1000 == 0:
        plt.imshow(np.rot90(np.rot90(np.rot90(currentObservation[:,:,0]))))
        plt.gca().invert_xaxis()
        plt.title('1')
        plt.show()
        
        plt.imshow(np.rot90(np.rot90(np.rot90(currentObservation[:,:,1]))))
        plt.gca().invert_xaxis()
        plt.title('2')
        plt.show()
        
        plt.imshow(np.rot90(np.rot90(np.rot90(currentObservation[:,:,2]))))
        plt.gca().invert_xaxis()
        plt.title('3')
        plt.show()
        
        plt.imshow(np.rot90(np.rot90(np.rot90(currentObservation[:,:,3]))))
        plt.gca().invert_xaxis()
        plt.title('4')
        plt.show()
        
    if timeStep % 10000 == 0:
        clear_output()
        
    timeStep += 1
# Out:
# 步数 1 Q值 [11.743    11.431611]===> 步数 1 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 0 / 最高得分 0
# 步数 2 Q值 [11.8420925 11.418408 ]===> 步数 2 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 0 / 最高得分 0
# 步数 3 Q值 [11.858492 11.352064]===> 步数 3 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 0 / 最高得分 0
# 步数 4 Q值 [11.860943  11.4511385]===> 步数 4 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 0 / 最高得分 0
# 步数 5 Q值 [11.943495 11.736685]===> 步数 5 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 0 / 最高得分 0
# 步数 6 Q值 [11.827222 11.634232]===> 步数 6 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 0 / 最高得分 0
# 步数 7 Q值 [11.871923 11.731438]===> 步数 7 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 0 / 最高得分 0
# 步数 8 Q值 [11.833257 11.777283]===> 步数 8 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 0 / 最高得分 0
# 步数 9 Q值 [11.841604 11.845508]===> 步数 9 / 本次行为 1 跳 / 本次奖励 0.1 / Running   / 当前分数 0 / 最高得分 0
# 步数 10 Q值 [11.953192 11.549301]===> 步数 10 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 0 / 最高得分 0
# 步数 11 Q值 [12.042881 11.68791 ]===> 步数 11 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 0 / 最高得分 0
# 步数 12 Q值 [11.9965925 11.844317 ]===> 步数 12 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 0 / 最高得分 0
# 步数 13 Q值 [11.932598 11.695676]===> 步数 13 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 0 / 最高得分 0
# 步数 14 Q值 [11.893108 11.577967]===> 步数 14 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 0 / 最高得分 0
# 步数 15 Q值 [11.849928 11.755984]===> 步数 15 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 0 / 最高得分 0
# 步数 16 Q值 [11.898012 11.793667]===> 步数 16 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 0 / 最高得分 0
# 步数 17 Q值 [11.840986  11.6361475]===> 步数 17 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 0 / 最高得分 0
# 步数 18 Q值 [11.784744 11.583459]===> 步数 18 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 0 / 最高得分 0
# 步数 19 Q值 [11.772157 11.570735]===> 步数 19 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 0 / 最高得分 0
# 步数 20 Q值 [11.753622 11.347182]===> 步数 20 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 0 / 最高得分 0
# 步数 21 Q值 [11.853727 11.551347]===> 步数 21 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 0 / 最高得分 0
# 步数 22 Q值 [11.799819 11.861969]===> 步数 22 / 本次行为 1 跳 / 本次奖励 0.1 / Running   / 当前分数 0 / 最高得分 0
# 步数 23 Q值 [11.89027  11.753772]===> 步数 23 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 0 / 最高得分 0
# 步数 24 Q值 [11.77345  11.639104]===> 步数 24 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 0 / 最高得分 0
# 步数 25 Q值 [11.905325 11.843808]===> 步数 25 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 0 / 最高得分 0
# 步数 26 Q值 [11.825861 11.749202]===> 步数 26 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 0 / 最高得分 0
# 步数 27 Q值 [11.840258 11.568159]===> 步数 27 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 0 / 最高得分 0
# 步数 28 Q值 [11.783146 11.553857]===> 步数 28 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 0 / 最高得分 0
# 步数 29 Q值 [11.738081 11.641331]===> 步数 29 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 0 / 最高得分 0
# 步数 30 Q值 [11.7766485 11.548358 ]===> 步数 30 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 0 / 最高得分 0
# 步数 31 Q值 [11.7553425 11.567087 ]===> 步数 31 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 0 / 最高得分 0
# 步数 32 Q值 [11.824552 11.470463]===> 步数 32 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 0 / 最高得分 0
# 步数 33 Q值 [11.818722 11.089505]===> 步数 33 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 0 / 最高得分 0
# 步数 34 Q值 [11.777374 10.839347]===> 步数 34 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 0 / 最高得分 0
# 步数 35 Q值 [11.940214 11.157209]===> 步数 35 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 0 / 最高得分 0
# 步数 36 Q值 [12.014028 11.40582 ]===> 步数 36 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 0 / 最高得分 0
# 步数 37 Q值 [12.154657 11.710805]===> 步数 37 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 0 / 最高得分 0
# 步数 38 Q值 [12.079562 11.87268 ]===> 步数 38 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 0 / 最高得分 0
# 步数 39 Q值 [11.910223 12.422791]===> 步数 39 / 本次行为 1 跳 / 本次奖励 0.1 / Running   / 当前分数 0 / 最高得分 0
# 步数 40 Q值 [12.436349 12.258867]===> 步数 40 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 0 / 最高得分 0
# 步数 41 Q值 [12.479317 11.939897]===> 步数 41 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 0 / 最高得分 0
# 步数 42 Q值 [12.386367 12.061039]===> 步数 42 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 0 / 最高得分 0
# 步数 43 Q值 [12.326066 12.024202]===> 步数 43 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 0 / 最高得分 0
# 步数 44 Q值 [12.286208  11.7993355]===> 步数 44 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 0 / 最高得分 0
# 步数 45 Q值 [12.350115 11.628142]===> 步数 45 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 0 / 最高得分 0
# 步数 46 Q值 [12.367738 11.517598]===> 步数 46 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 0 / 最高得分 0
# 步数 47 Q值 [12.420309 11.400849]===> 步数 47 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 0 / 最高得分 0
# 步数 48 Q值 [12.280236 11.315459]===> 步数 48 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 0 / 最高得分 0
# 步数 49 Q值 [12.48457  11.844906]===> 步数 49 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 0 / 最高得分 0
# 步数 50 Q值 [12.257877 12.156871]===> 步数 50 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 0 / 最高得分 0
# 步数 51 Q值 [12.237223 12.724644]===> 步数 51 / 本次行为 1 跳 / 本次奖励 0.1 / Running   / 当前分数 0 / 最高得分 0
# 步数 52 Q值 [12.5051985 11.181184 ]===> 步数 52 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 0 / 最高得分 0
# 步数 53 Q值 [12.5744    8.598734]===> 步数 53 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 0 / 最高得分 0
# 步数 54 Q值 [12.489863  7.113654]===> 步数 54 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 0 / 最高得分 0
# 步数 55 Q值 [12.507427   4.9298134]===> 步数 55 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 0 / 最高得分 0
# 步数 56 Q值 [12.531775  2.78379 ]===> 步数 56 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 0 / 最高得分 0
# 步数 57 Q值 [12.863207  2.947409]===> 步数 57 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 0 / 最高得分 0
# 步数 58 Q值 [12.742993  2.464424]===> 步数 58 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 0 / 最高得分 0
# 步数 59 Q值 [12.734586  3.136019]===> 步数 59 / 本次行为 0 不跳 / 本次奖励 1 / Running   / 当前分数 1 / 最高得分 1
# 步数 60 Q值 [12.116985   2.7453988]===> 步数 60 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 1 / 最高得分 1
# 步数 61 Q值 [12.063738   2.5410194]===> 步数 61 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 1 / 最高得分 1
# 步数 62 Q值 [11.888732  3.340576]===> 步数 62 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 1 / 最高得分 1
# 步数 63 Q值 [11.934847   5.8018365]===> 步数 63 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 1 / 最高得分 1
# 步数 64 Q值 [11.950898   7.3743687]===> 步数 64 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 1 / 最高得分 1
# 步数 65 Q值 [11.883515  9.600352]===> 步数 65 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 1 / 最高得分 1
# 步数 66 Q值 [11.850814 10.021362]===> 步数 66 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 1 / 最高得分 1
# 步数 67 Q值 [11.946479 10.592622]===> 步数 67 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 1 / 最高得分 1
# 步数 68 Q值 [11.973012 10.95537 ]===> 步数 68 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 1 / 最高得分 1
# 步数 69 Q值 [11.994985 11.682421]===> 步数 69 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 1 / 最高得分 1
# 步数 70 Q值 [12.08068  11.031757]===> 步数 70 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 1 / 最高得分 1
# 步数 71 Q值 [12.002314 10.206567]===> 步数 71 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 1 / 最高得分 1
# 步数 72 Q值 [11.982357 10.697059]===> 步数 72 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 1 / 最高得分 1
# 步数 73 Q值 [12.118882 11.278695]===> 步数 73 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 1 / 最高得分 1
# 步数 74 Q值 [11.953299 11.158138]===> 步数 74 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 1 / 最高得分 1
# 步数 75 Q值 [11.970872 11.646765]===> 步数 75 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 1 / 最高得分 1
# 步数 76 Q值 [12.211751 12.237768]===> 步数 76 / 本次行为 1 跳 / 本次奖励 0.1 / Running   / 当前分数 1 / 最高得分 1
# 步数 77 Q值 [12.030794 11.592688]===> 步数 77 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 1 / 最高得分 1
# 步数 78 Q值 [12.27795  12.210876]===> 步数 78 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 1 / 最高得分 1
# 步数 79 Q值 [12.347845 12.393867]===> 步数 79 / 本次行为 1 跳 / 本次奖励 0.1 / Running   / 当前分数 1 / 最高得分 1
# 步数 80 Q值 [12.3304405 11.436047 ]===> 步数 80 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 1 / 最高得分 1
# 步数 81 Q值 [12.132597 10.942829]===> 步数 81 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 1 / 最高得分 1
# 步数 82 Q值 [12.000683 10.224381]===> 步数 82 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 1 / 最高得分 1
# 步数 83 Q值 [12.116792  9.516003]===> 步数 83 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 1 / 最高得分 1
# 步数 84 Q值 [11.962515  7.241704]===> 步数 84 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 1 / 最高得分 1
# 步数 85 Q值 [12.142966   4.4749646]===> 步数 85 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 1 / 最高得分 1
# 步数 86 Q值 [12.191454   4.7704577]===> 步数 86 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 1 / 最高得分 1
# 步数 87 Q值 [12.368999   4.9707246]===> 步数 87 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 1 / 最高得分 1
# 步数 88 Q值 [12.461615   5.5542235]===> 步数 88 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 1 / 最高得分 1
# 步数 89 Q值 [12.500523   4.9692492]===> 步数 89 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 1 / 最高得分 1
# 步数 90 Q值 [12.516815  6.067864]===> 步数 90 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 1 / 最高得分 1
# 步数 91 Q值 [12.450468   6.8110075]===> 步数 91 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 1 / 最高得分 1
# 步数 92 Q值 [12.451933  9.145092]===> 步数 92 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 1 / 最高得分 1
# 步数 93 Q值 [12.45021   10.6614685]===> 步数 93 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 1 / 最高得分 1
# 步数 94 Q值 [12.583626 11.784163]===> 步数 94 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 1 / 最高得分 1
# 步数 95 Q值 [12.675054 12.258346]===> 步数 95 / 本次行为 0 不跳 / 本次奖励 1 / Running   / 当前分数 2 / 最高得分 2
# 步数 96 Q值 [11.612935 11.666348]===> 步数 96 / 本次行为 1 跳 / 本次奖励 0.1 / Running   / 当前分数 2 / 最高得分 2
# 步数 97 Q值 [11.7389965 10.536154 ]===> 步数 97 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 2 / 最高得分 2
# 步数 98 Q值 [11.793881  7.91386 ]===> 步数 98 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 2 / 最高得分 2
# 步数 99 Q值 [11.781889  8.390308]===> 步数 99 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 2 / 最高得分 2
# 步数 100 Q值 [11.890054  8.577925]===> 步数 100 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 2 / 最高得分 2
# 步数 101 Q值 [11.819343  8.536139]===> 步数 101 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 2 / 最高得分 2
# 步数 102 Q值 [11.899986  8.688564]===> 步数 102 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 2 / 最高得分 2
# 步数 103 Q值 [11.950821  9.839161]===> 步数 103 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 2 / 最高得分 2
# 步数 104 Q值 [11.98888   9.879987]===> 步数 104 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 2 / 最高得分 2
# 步数 105 Q值 [11.881714  9.891567]===> 步数 105 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 2 / 最高得分 2
# 步数 106 Q值 [11.894079  9.848421]===> 步数 106 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 2 / 最高得分 2
# 步数 107 Q值 [11.85005   9.652868]===> 步数 107 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 2 / 最高得分 2
# 步数 108 Q值 [11.931875 10.665004]===> 步数 108 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 2 / 最高得分 2
# 步数 109 Q值 [12.012478  10.6721325]===> 步数 109 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 2 / 最高得分 2
# 步数 110 Q值 [12.095793 11.156813]===> 步数 110 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 2 / 最高得分 2
# 步数 111 Q值 [12.046759 11.29846 ]===> 步数 111 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 2 / 最高得分 2
# 步数 112 Q值 [12.023065 11.622068]===> 步数 112 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 2 / 最高得分 2
# 步数 113 Q值 [12.089208 11.595171]===> 步数 113 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 2 / 最高得分 2
# 步数 114 Q值 [12.112825 11.550297]===> 步数 114 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 2 / 最高得分 2
# 步数 115 Q值 [11.424527 11.988527]===> 步数 115 / 本次行为 1 跳 / 本次奖励 0.1 / Running   / 当前分数 2 / 最高得分 2
# 步数 116 Q值 [12.060171 11.765764]===> 步数 116 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 2 / 最高得分 2
# 步数 117 Q值 [12.061563 11.763278]===> 步数 117 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 2 / 最高得分 2
# 步数 118 Q值 [12.12518  11.471779]===> 步数 118 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 2 / 最高得分 2
# 步数 119 Q值 [12.214842 11.799489]===> 步数 119 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 2 / 最高得分 2
# 步数 120 Q值 [12.227411 11.999177]===> 步数 120 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 2 / 最高得分 2
# 步数 121 Q值 [12.359899 12.019802]===> 步数 121 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 2 / 最高得分 2
# 步数 122 Q值 [12.275793 11.869374]===> 步数 122 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 2 / 最高得分 2
# 步数 123 Q值 [12.362354 11.827518]===> 步数 123 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 2 / 最高得分 2
# 步数 124 Q值 [12.3235655 11.692024 ]===> 步数 124 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 2 / 最高得分 2
# 步数 125 Q值 [12.266999 11.53265 ]===> 步数 125 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 2 / 最高得分 2
# 步数 126 Q值 [12.303234 11.884956]===> 步数 126 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 2 / 最高得分 2
# 步数 127 Q值 [11.900888 12.166585]===> 步数 127 / 本次行为 1 跳 / 本次奖励 0.1 / Running   / 当前分数 2 / 最高得分 2
# 步数 128 Q值 [12.40422   11.3263035]===> 步数 128 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 2 / 最高得分 2
# 步数 129 Q值 [12.414943 10.69954 ]===> 步数 129 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 2 / 最高得分 2
# 步数 130 Q值 [12.42268  10.609856]===> 步数 130 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 2 / 最高得分 2
# 步数 131 Q值 [12.566527   7.6223445]===> 步数 131 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 2 / 最高得分 2
# 步数 132 Q值 [12.541606  8.048137]===> 步数 132 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 2 / 最高得分 2
# 步数 133 Q值 [12.628391  6.723656]===> 步数 133 / 本次行为 0 不跳 / 本次奖励 1 / Running   / 当前分数 3 / 最高得分 3
# 步数 134 Q值 [11.694856  2.354299]===> 步数 134 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 3 / 最高得分 3
# 步数 135 Q值 [11.7552    2.451154]===> 步数 135 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 3 / 最高得分 3
# 步数 136 Q值 [11.745302  2.85628 ]===> 步数 136 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 3 / 最高得分 3
# 步数 137 Q值 [11.7181015  4.185431 ]===> 步数 137 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 3 / 最高得分 3
# 步数 138 Q值 [11.800201  5.181498]===> 步数 138 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 3 / 最高得分 3
# 步数 139 Q值 [11.8442955  7.058216 ]===> 步数 139 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 3 / 最高得分 3
# 步数 140 Q值 [11.797979  9.687685]===> 步数 140 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 3 / 最高得分 3
# 步数 141 Q值 [11.82969   10.2297945]===> 步数 141 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 3 / 最高得分 3
# 步数 142 Q值 [11.863817 10.522248]===> 步数 142 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 3 / 最高得分 3
# 步数 143 Q值 [11.942872 10.657686]===> 步数 143 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 3 / 最高得分 3
# 步数 144 Q值 [11.989761 10.792958]===> 步数 144 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 3 / 最高得分 3
# 步数 145 Q值 [12.032085 10.875811]===> 步数 145 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 3 / 最高得分 3
# 步数 146 Q值 [12.059334 10.892163]===> 步数 146 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 3 / 最高得分 3
# 步数 147 Q值 [12.085294 11.377913]===> 步数 147 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 3 / 最高得分 3
# 步数 148 Q值 [11.945701 11.500758]===> 步数 148 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 3 / 最高得分 3
# 步数 149 Q值 [12.002075 12.217933]===> 步数 149 / 本次行为 1 跳 / 本次奖励 0.1 / Running   / 当前分数 3 / 最高得分 3
# 步数 150 Q值 [11.928886 12.204597]===> 步数 150 / 本次行为 1 跳 / 本次奖励 0.1 / Running   / 当前分数 3 / 最高得分 3
# 步数 151 Q值 [12.041165 11.370408]===> 步数 151 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 3 / 最高得分 3
# 步数 152 Q值 [12.08132  11.045855]===> 步数 152 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 3 / 最高得分 3
# 步数 153 Q值 [12.109106 10.684981]===> 步数 153 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 3 / 最高得分 3
# 步数 154 Q值 [12.065457 10.197616]===> 步数 154 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 3 / 最高得分 3
# 步数 155 Q值 [11.999844 10.391951]===> 步数 155 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 3 / 最高得分 3
# 步数 156 Q值 [12.030399  9.245223]===> 步数 156 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 3 / 最高得分 3
# 步数 157 Q值 [12.134632  6.904123]===> 步数 157 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 3 / 最高得分 3
# 步数 158 Q值 [12.265521   7.6798244]===> 步数 158 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 3 / 最高得分 3
# 步数 159 Q值 [12.35509   8.259551]===> 步数 159 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 3 / 最高得分 3
# 步数 160 Q值 [12.363622  8.140028]===> 步数 160 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 3 / 最高得分 3
# 步数 161 Q值 [12.341834  8.166824]===> 步数 161 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 3 / 最高得分 3
# 步数 162 Q值 [12.332944  9.11683 ]===> 步数 162 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 3 / 最高得分 3
# 步数 163 Q值 [12.439985  9.877969]===> 步数 163 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 3 / 最高得分 3
# 步数 164 Q值 [12.42592  11.088821]===> 步数 164 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 3 / 最高得分 3
# 步数 165 Q值 [12.426873 11.30699 ]===> 步数 165 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 3 / 最高得分 3
# 步数 166 Q值 [12.237589 11.982621]===> 步数 166 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 3 / 最高得分 3
# 步数 167 Q值 [ 8.861737 12.351123]===> 步数 167 / 本次行为 1 跳 / 本次奖励 0.1 / Running   / 当前分数 3 / 最高得分 3
# 步数 168 Q值 [12.279922 12.169835]===> 步数 168 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 3 / 最高得分 3
# 步数 169 Q值 [12.474406 11.055396]===> 步数 169 / 本次行为 0 不跳 / 本次奖励 1 / Running   / 当前分数 4 / 最高得分 4
# 步数 170 Q值 [11.720351 10.225237]===> 步数 170 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 4 / 最高得分 4
# 步数 171 Q值 [11.691918  9.716134]===> 步数 171 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 4 / 最高得分 4
# 步数 172 Q值 [11.730309   9.0119095]===> 步数 172 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 4 / 最高得分 4
# 步数 173 Q值 [11.760331  9.535789]===> 步数 173 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 4 / 最高得分 4
# 步数 174 Q值 [11.838807  9.798546]===> 步数 174 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 4 / 最高得分 4
# 步数 175 Q值 [11.772551  9.386792]===> 步数 175 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 4 / 最高得分 4
# 步数 176 Q值 [11.828224  9.465654]===> 步数 176 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 4 / 最高得分 4
# 步数 177 Q值 [11.778529  9.689523]===> 步数 177 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 4 / 最高得分 4
# 步数 178 Q值 [11.783133  9.539553]===> 步数 178 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 4 / 最高得分 4
# 步数 179 Q值 [11.803972  9.894728]===> 步数 179 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 4 / 最高得分 4
# 步数 180 Q值 [11.795417  9.921122]===> 步数 180 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 4 / 最高得分 4
# 步数 181 Q值 [11.781754  9.573443]===> 步数 181 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 4 / 最高得分 4
# 步数 182 Q值 [11.891314  8.897047]===> 步数 182 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 4 / 最高得分 4
# 步数 183 Q值 [11.943904  9.248418]===> 步数 183 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 4 / 最高得分 4
# 步数 184 Q值 [11.9670925 10.077223 ]===> 步数 184 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 4 / 最高得分 4
# 步数 185 Q值 [12.042376 10.73742 ]===> 步数 185 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 4 / 最高得分 4
# 步数 186 Q值 [12.085363  10.6526375]===> 步数 186 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 4 / 最高得分 4
# 步数 187 Q值 [12.079955 11.295246]===> 步数 187 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 4 / 最高得分 4
# 步数 188 Q值 [12.0785055 11.403364 ]===> 步数 188 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 4 / 最高得分 4
# 步数 189 Q值 [11.843082 12.235936]===> 步数 189 / 本次行为 1 跳 / 本次奖励 0.1 / Running   / 当前分数 4 / 最高得分 4
# 步数 190 Q值 [12.063791 12.082597]===> 步数 190 / 本次行为 1 跳 / 本次奖励 0.1 / Running   / 当前分数 4 / 最高得分 4
# 步数 191 Q值 [12.201783 11.562605]===> 步数 191 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 4 / 最高得分 4
# 步数 192 Q值 [12.195904  11.3800535]===> 步数 192 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 4 / 最高得分 4
# 步数 193 Q值 [12.217738 11.482912]===> 步数 193 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 4 / 最高得分 4
# 步数 194 Q值 [12.287572 11.703865]===> 步数 194 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 4 / 最高得分 4
# 步数 195 Q值 [12.172241 11.054544]===> 步数 195 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 4 / 最高得分 4
# 步数 196 Q值 [12.173402 10.995379]===> 步数 196 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 4 / 最高得分 4
# 步数 197 Q值 [12.387986 10.645939]===> 步数 197 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 4 / 最高得分 4
# 步数 198 Q值 [12.5021   10.004142]===> 步数 198 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 4 / 最高得分 4
# 步数 199 Q值 [12.519333 10.089172]===> 步数 199 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 4 / 最高得分 4
# 步数 200 Q值 [12.522164 10.399262]===> 步数 200 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 4 / 最高得分 4
# 步数 201 Q值 [12.59505  10.098907]===> 步数 201 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 4 / 最高得分 4
# 步数 202 Q值 [12.685466 10.610326]===> 步数 202 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 4 / 最高得分 4
# 步数 203 Q值 [12.631239 11.347918]===> 步数 203 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 4 / 最高得分 4
# 步数 204 Q值 [12.617603 11.861185]===> 步数 204 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 4 / 最高得分 4
# 步数 205 Q值 [12.402691 12.277547]===> 步数 205 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 4 / 最高得分 4
# 步数 206 Q值 [ 8.798715 12.541347]===> 步数 206 / 本次行为 1 跳 / 本次奖励 0.1 / Running   / 当前分数 4 / 最高得分 4
# 步数 207 Q值 [12.678038 11.960361]===> 步数 207 / 本次行为 0 不跳 / 本次奖励 1 / Running   / 当前分数 5 / 最高得分 5
# 步数 208 Q值 [11.880138 10.418932]===> 步数 208 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 5 / 最高得分 5
# 步数 209 Q值 [11.886311 10.09536 ]===> 步数 209 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 5 / 最高得分 5
# 步数 210 Q值 [11.863907  9.607383]===> 步数 210 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 5 / 最高得分 5
# 步数 211 Q值 [11.799643  9.630983]===> 步数 211 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 5 / 最高得分 5
# 步数 212 Q值 [11.966597  9.731905]===> 步数 212 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 5 / 最高得分 5
# 步数 213 Q值 [12.056794  9.633944]===> 步数 213 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 5 / 最高得分 5
# 步数 214 Q值 [12.060314  8.878163]===> 步数 214 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 5 / 最高得分 5
# 步数 215 Q值 [11.980734  8.628498]===> 步数 215 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 5 / 最高得分 5
# 步数 216 Q值 [12.009672  8.306939]===> 步数 216 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 5 / 最高得分 5
# 步数 217 Q值 [12.043242  9.029207]===> 步数 217 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 5 / 最高得分 5
# 步数 218 Q值 [11.9872     6.9331007]===> 步数 218 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 5 / 最高得分 5
# 步数 219 Q值 [12.099433  5.642029]===> 步数 219 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 5 / 最高得分 5
# 步数 220 Q值 [12.144357   3.8791664]===> 步数 220 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 5 / 最高得分 5
# 步数 221 Q值 [12.200702   3.2476525]===> 步数 221 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 5 / 最高得分 5
# 步数 222 Q值 [12.220618   3.2013786]===> 步数 222 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 5 / 最高得分 5
# 步数 223 Q值 [12.236121   3.9868782]===> 步数 223 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 5 / 最高得分 5
# 步数 224 Q值 [12.163793  4.275476]===> 步数 224 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 5 / 最高得分 5
# 步数 225 Q值 [12.211523  6.668984]===> 步数 225 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 5 / 最高得分 5
# 步数 226 Q值 [12.24705   9.819128]===> 步数 226 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 5 / 最高得分 5
# 步数 227 Q值 [12.286077 10.925901]===> 步数 227 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 5 / 最高得分 5
# 步数 228 Q值 [12.227474 11.667247]===> 步数 228 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 5 / 最高得分 5
# 步数 229 Q值 [12.150083 12.302913]===> 步数 229 / 本次行为 1 跳 / 本次奖励 0.1 / Running   / 当前分数 5 / 最高得分 5
# 步数 230 Q值 [12.407243 11.750884]===> 步数 230 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 5 / 最高得分 5
# 步数 231 Q值 [12.466421 10.979745]===> 步数 231 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 5 / 最高得分 5
# 步数 232 Q值 [12.478286 10.856688]===> 步数 232 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 5 / 最高得分 5
# 步数 233 Q值 [12.565957 10.536753]===> 步数 233 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 5 / 最高得分 5
# 步数 234 Q值 [12.4969015  9.412267 ]===> 步数 234 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 5 / 最高得分 5
# 步数 235 Q值 [12.512709   7.4337845]===> 步数 235 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 5 / 最高得分 5
# 步数 236 Q值 [12.533131  6.540442]===> 步数 236 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 5 / 最高得分 5
# 步数 237 Q值 [12.592642   4.9254684]===> 步数 237 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 5 / 最高得分 5
# 步数 238 Q值 [12.583518   5.0155687]===> 步数 238 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 5 / 最高得分 5
# 步数 239 Q值 [12.510443  5.172032]===> 步数 239 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 5 / 最高得分 5
# 步数 240 Q值 [12.448047   5.3686986]===> 步数 240 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 5 / 最高得分 5
# 步数 241 Q值 [12.487142   7.1901455]===> 步数 241 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 5 / 最高得分 5
# 步数 242 Q值 [12.4884405  9.310349 ]===> 步数 242 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 5 / 最高得分 5
# 步数 243 Q值 [12.59182  10.549288]===> 步数 243 / 本次行为 0 不跳 / 本次奖励 1 / Running   / 当前分数 6 / 最高得分 6
# 步数 244 Q值 [11.698258 10.170505]===> 步数 244 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 6 / 最高得分 6
# 步数 245 Q值 [11.73769  11.260918]===> 步数 245 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 6 / 最高得分 6
# 步数 246 Q值 [10.903631 12.180135]===> 步数 246 / 本次行为 1 跳 / 本次奖励 0.1 / Running   / 当前分数 6 / 最高得分 6
# 步数 247 Q值 [11.866699 11.414603]===> 步数 247 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 6 / 最高得分 6
# 步数 248 Q值 [11.916822 11.221746]===> 步数 248 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 6 / 最高得分 6
# 步数 249 Q值 [11.856822 10.955222]===> 步数 249 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 6 / 最高得分 6
# 步数 250 Q值 [11.914114  10.9953575]===> 步数 250 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 6 / 最高得分 6
# 步数 251 Q值 [11.913693 10.808407]===> 步数 251 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 6 / 最高得分 6
# 步数 252 Q值 [11.877988 10.68542 ]===> 步数 252 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 6 / 最高得分 6
# 步数 253 Q值 [11.897697 10.444491]===> 步数 253 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 6 / 最高得分 6
# 步数 254 Q值 [11.914725 10.08892 ]===> 步数 254 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 6 / 最高得分 6
# 步数 255 Q值 [11.966421  9.534646]===> 步数 255 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 6 / 最高得分 6
# 步数 256 Q值 [11.955469  7.33969 ]===> 步数 256 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 6 / 最高得分 6
# 步数 257 Q值 [12.046315  6.601743]===> 步数 257 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 6 / 最高得分 6
# 步数 258 Q值 [12.002486  6.134817]===> 步数 258 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 6 / 最高得分 6
# 步数 259 Q值 [12.082728   5.8542314]===> 步数 259 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 6 / 最高得分 6
# 步数 260 Q值 [12.124934  6.383866]===> 步数 260 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 6 / 最高得分 6
# 步数 261 Q值 [12.15481    6.9527144]===> 步数 261 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 6 / 最高得分 6
# 步数 262 Q值 [12.130925  8.822035]===> 步数 262 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 6 / 最高得分 6
# 步数 263 Q值 [12.110206  9.895014]===> 步数 263 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 6 / 最高得分 6
# 步数 264 Q值 [12.037134 10.585796]===> 步数 264 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 6 / 最高得分 6
# 步数 265 Q值 [12.149983 11.093228]===> 步数 265 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 6 / 最高得分 6
# 步数 266 Q值 [11.865769 12.228561]===> 步数 266 / 本次行为 1 跳 / 本次奖励 0.1 / Running   / 当前分数 6 / 最高得分 6
# 步数 267 Q值 [12.287581 12.123024]===> 步数 267 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 6 / 最高得分 6
# 步数 268 Q值 [12.378856 11.354773]===> 步数 268 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 6 / 最高得分 6
# 步数 269 Q值 [12.282652 10.785613]===> 步数 269 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 6 / 最高得分 6
# 步数 270 Q值 [12.28368  10.009012]===> 步数 270 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 6 / 最高得分 6
# 步数 271 Q值 [12.385564  9.130157]===> 步数 271 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 6 / 最高得分 6
# 步数 272 Q值 [12.412031  8.075165]===> 步数 272 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 6 / 最高得分 6
# 步数 273 Q值 [12.425155  6.306221]===> 步数 273 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 6 / 最高得分 6
# 步数 274 Q值 [12.4708185  5.3364196]===> 步数 274 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 6 / 最高得分 6
# 步数 275 Q值 [12.533742  5.209631]===> 步数 275 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 6 / 最高得分 6
# 步数 276 Q值 [12.573894  4.764685]===> 步数 276 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 6 / 最高得分 6
# 步数 277 Q值 [12.595694   5.7741833]===> 步数 277 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 6 / 最高得分 6
# 步数 278 Q值 [12.684535  6.171481]===> 步数 278 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 6 / 最高得分 6
# 步数 279 Q值 [12.777713  8.321033]===> 步数 279 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 6 / 最高得分 6
# 步数 280 Q值 [12.617487  9.635367]===> 步数 280 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 6 / 最高得分 6
# 步数 281 Q值 [12.588658 11.249174]===> 步数 281 / 本次行为 0 不跳 / 本次奖励 1 / Running   / 当前分数 7 / 最高得分 7
# 步数 282 Q值 [11.741088 10.998916]===> 步数 282 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 7 / 最高得分 7
# 步数 283 Q值 [11.044413 11.96287 ]===> 步数 283 / 本次行为 1 跳 / 本次奖励 0.1 / Running   / 当前分数 7 / 最高得分 7
# 步数 284 Q值 [11.822336 11.059215]===> 步数 284 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 7 / 最高得分 7
# 步数 285 Q值 [11.826492 10.677035]===> 步数 285 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 7 / 最高得分 7
# 步数 286 Q值 [11.832378 10.236225]===> 步数 286 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 7 / 最高得分 7
# 步数 287 Q值 [11.770312 10.251937]===> 步数 287 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 7 / 最高得分 7
# 步数 288 Q值 [11.792994 10.257566]===> 步数 288 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 7 / 最高得分 7
# 步数 289 Q值 [11.7989025 10.429063 ]===> 步数 289 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 7 / 最高得分 7
# 步数 290 Q值 [11.877055  9.794771]===> 步数 290 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 7 / 最高得分 7
# 步数 291 Q值 [11.843786  9.831543]===> 步数 291 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 7 / 最高得分 7
# 步数 292 Q值 [11.9330435  9.905267 ]===> 步数 292 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 7 / 最高得分 7
# 步数 293 Q值 [12.031322  9.519393]===> 步数 293 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 7 / 最高得分 7
# 步数 294 Q值 [12.102733  9.58035 ]===> 步数 294 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 7 / 最高得分 7
# 步数 295 Q值 [12.142324  9.653548]===> 步数 295 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 7 / 最高得分 7
# 步数 296 Q值 [12.188947  9.953995]===> 步数 296 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 7 / 最高得分 7
# 步数 297 Q值 [12.226476 10.161673]===> 步数 297 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 7 / 最高得分 7
# 步数 298 Q值 [12.225622 10.353096]===> 步数 298 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 7 / 最高得分 7
# 步数 299 Q值 [12.241346 11.270451]===> 步数 299 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 7 / 最高得分 7
# 步数 300 Q值 [12.239435 12.061948]===> 步数 300 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 7 / 最高得分 7
# 步数 301 Q值 [12.097224 12.14854 ]===> 步数 301 / 本次行为 1 跳 / 本次奖励 0.1 / Running   / 当前分数 7 / 最高得分 7
# 步数 302 Q值 [12.202887 11.711501]===> 步数 302 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 7 / 最高得分 7
# 步数 303 Q值 [12.172442 11.056692]===> 步数 303 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 7 / 最高得分 7
# 步数 304 Q值 [12.092139 11.232559]===> 步数 304 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 7 / 最高得分 7
# 步数 305 Q值 [12.153154 10.067734]===> 步数 305 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 7 / 最高得分 7
# 步数 306 Q值 [12.301944 10.036428]===> 步数 306 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 7 / 最高得分 7
# 步数 307 Q值 [12.4445915  8.794441 ]===> 步数 307 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 7 / 最高得分 7
# 步数 308 Q值 [12.464549  8.360256]===> 步数 308 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 7 / 最高得分 7
# 步数 309 Q值 [12.460533  7.630687]===> 步数 309 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 7 / 最高得分 7
# 步数 310 Q值 [12.452557   7.0256443]===> 步数 310 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 7 / 最高得分 7
# 步数 311 Q值 [12.457389   6.8980412]===> 步数 311 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 7 / 最高得分 7
# 步数 312 Q值 [12.53114    6.1775756]===> 步数 312 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 7 / 最高得分 7
# 步数 313 Q值 [12.557235   6.3524866]===> 步数 313 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 7 / 最高得分 7
# 步数 314 Q值 [12.5287695  7.603688 ]===> 步数 314 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 7 / 最高得分 7
# 步数 315 Q值 [12.503613 10.073888]===> 步数 315 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 7 / 最高得分 7
# 步数 316 Q值 [12.6032505 11.150926 ]===> 步数 316 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 7 / 最高得分 7
# 步数 317 Q值 [12.518609 11.552821]===> 步数 317 / 本次行为 0 不跳 / 本次奖励 1 / Running   / 当前分数 8 / 最高得分 8
# 步数 318 Q值 [ 8.314791 11.999221]===> 步数 318 / 本次行为 1 跳 / 本次奖励 0.1 / Running   / 当前分数 8 / 最高得分 8
# 步数 319 Q值 [11.803397 10.541038]===> 步数 319 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 8 / 最高得分 8
# 步数 320 Q值 [11.77297  10.278947]===> 步数 320 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 8 / 最高得分 8
# 步数 321 Q值 [11.725013 10.516066]===> 步数 321 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 8 / 最高得分 8
# 步数 322 Q值 [11.82793  10.818081]===> 步数 322 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 8 / 最高得分 8
# 步数 323 Q值 [11.890452  9.947759]===> 步数 323 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 8 / 最高得分 8
# 步数 324 Q值 [11.957384  8.85065 ]===> 步数 324 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 8 / 最高得分 8
# 步数 325 Q值 [11.882061   7.4353795]===> 步数 325 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 8 / 最高得分 8
# 步数 326 Q值 [11.937035   6.1493025]===> 步数 326 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 8 / 最高得分 8
# 步数 327 Q值 [11.854162   5.8299084]===> 步数 327 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 8 / 最高得分 8
# 步数 328 Q值 [11.815471  4.913587]===> 步数 328 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 8 / 最高得分 8
# 步数 329 Q值 [11.87942    4.5475254]===> 步数 329 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 8 / 最高得分 8
# 步数 330 Q值 [11.868543   4.9223676]===> 步数 330 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 8 / 最高得分 8
# 步数 331 Q值 [11.967086  5.785567]===> 步数 331 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 8 / 最高得分 8
# 步数 332 Q值 [11.926172  6.073221]===> 步数 332 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 8 / 最高得分 8
# 步数 333 Q值 [11.946611  5.489215]===> 步数 333 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 8 / 最高得分 8
# 步数 334 Q值 [11.992763   4.4923005]===> 步数 334 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 8 / 最高得分 8
# 步数 335 Q值 [12.03921    4.1756134]===> 步数 335 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 8 / 最高得分 8
# 步数 336 Q值 [12.077057  5.092251]===> 步数 336 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 8 / 最高得分 8
# 步数 337 Q值 [12.08596    6.4040823]===> 步数 337 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 8 / 最高得分 8
# 步数 338 Q值 [12.133612   8.9178095]===> 步数 338 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 8 / 最高得分 8
# 步数 339 Q值 [12.166381 10.851295]===> 步数 339 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 8 / 最高得分 8
# 步数 340 Q值 [12.025831 12.056363]===> 步数 340 / 本次行为 1 跳 / 本次奖励 0.1 / Running   / 当前分数 8 / 最高得分 8
# 步数 341 Q值 [12.355877 12.011695]===> 步数 341 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 8 / 最高得分 8
# 步数 342 Q值 [12.324616 11.536249]===> 步数 342 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 8 / 最高得分 8
# 步数 343 Q值 [12.278638 11.134619]===> 步数 343 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 8 / 最高得分 8
# 步数 344 Q值 [12.324518 10.407542]===> 步数 344 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 8 / 最高得分 8
# 步数 345 Q值 [12.355262  9.93914 ]===> 步数 345 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 8 / 最高得分 8
# 步数 346 Q值 [12.470531  8.254683]===> 步数 346 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 8 / 最高得分 8
# 步数 347 Q值 [12.499475   6.6413574]===> 步数 347 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 8 / 最高得分 8
# 步数 348 Q值 [12.461768   4.8547335]===> 步数 348 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 8 / 最高得分 8
# 步数 349 Q值 [12.573131  5.173329]===> 步数 349 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 8 / 最高得分 8
# 步数 350 Q值 [12.590666  5.178201]===> 步数 350 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 8 / 最高得分 8
# 步数 351 Q值 [12.577596   5.1259985]===> 步数 351 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 8 / 最高得分 8
# 步数 352 Q值 [12.6027355  5.349086 ]===> 步数 352 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 8 / 最高得分 8
# 步数 353 Q值 [12.589332   6.9689565]===> 步数 353 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 8 / 最高得分 8
# 步数 354 Q值 [12.624235 10.641727]===> 步数 354 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 8 / 最高得分 8
# 步数 355 Q值 [12.65526  10.889722]===> 步数 355 / 本次行为 0 不跳 / 本次奖励 1 / Running   / 当前分数 9 / 最高得分 9
# 步数 356 Q值 [11.843821 10.776161]===> 步数 356 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 9 / 最高得分 9
# 步数 357 Q值 [11.699276 11.713129]===> 步数 357 / 本次行为 1 跳 / 本次奖励 0.1 / Running   / 当前分数 9 / 最高得分 9
# 步数 358 Q值 [11.801999  10.9433365]===> 步数 358 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 9 / 最高得分 9
# 步数 359 Q值 [11.778294 10.793995]===> 步数 359 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 9 / 最高得分 9
# 步数 360 Q值 [11.910201 10.481604]===> 步数 360 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 9 / 最高得分 9
# 步数 361 Q值 [12.060651 10.086689]===> 步数 361 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 9 / 最高得分 9
# 步数 362 Q值 [12.052671  8.967289]===> 步数 362 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 9 / 最高得分 9
# 步数 363 Q值 [11.981313  9.016118]===> 步数 363 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 9 / 最高得分 9
# 步数 364 Q值 [12.016289  8.782052]===> 步数 364 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 9 / 最高得分 9
# 步数 365 Q值 [12.032692  9.26952 ]===> 步数 365 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 9 / 最高得分 9
# 步数 366 Q值 [11.990084   6.7922606]===> 步数 366 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 9 / 最高得分 9
# 步数 367 Q值 [12.107393   4.5467777]===> 步数 367 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 9 / 最高得分 9
# 步数 368 Q值 [12.146745  3.361113]===> 步数 368 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 9 / 最高得分 9
# 步数 369 Q值 [12.149534   3.1924856]===> 步数 369 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 9 / 最高得分 9
# 步数 370 Q值 [12.17448    3.2938943]===> 步数 370 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 9 / 最高得分 9
# 步数 371 Q值 [12.167069   2.3108237]===> 步数 371 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 9 / 最高得分 9
# 步数 372 Q值 [12.228996   1.1189167]===> 步数 372 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 9 / 最高得分 9
# 步数 373 Q值 [12.219047   1.4211314]===> 步数 373 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 9 / 最高得分 9
# 步数 374 Q值 [12.248123   3.4812543]===> 步数 374 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 9 / 最高得分 9
# 步数 375 Q值 [12.240841  3.614493]===> 步数 375 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 9 / 最高得分 9
# 步数 376 Q值 [12.217657   6.7875314]===> 步数 376 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 9 / 最高得分 9
# 步数 377 Q值 [12.278832 10.567934]===> 步数 377 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 9 / 最高得分 9
# 步数 378 Q值 [12.31488  11.190111]===> 步数 378 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 9 / 最高得分 9
# 步数 379 Q值 [11.97827  12.429627]===> 步数 379 / 本次行为 1 跳 / 本次奖励 0.1 / Running   / 当前分数 9 / 最高得分 9
# 步数 380 Q值 [12.371634 11.849826]===> 步数 380 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 9 / 最高得分 9
# 步数 381 Q值 [12.516771 10.881083]===> 步数 381 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 9 / 最高得分 9
# 步数 382 Q值 [12.454889 10.609122]===> 步数 382 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 9 / 最高得分 9
# 步数 383 Q值 [12.580426  8.130489]===> 步数 383 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 9 / 最高得分 9
# 步数 384 Q值 [12.586274   6.8132997]===> 步数 384 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 9 / 最高得分 9
# 步数 385 Q值 [12.592742   4.6356893]===> 步数 385 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 9 / 最高得分 9
# 步数 386 Q值 [12.686511   3.7728245]===> 步数 386 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 9 / 最高得分 9
# 步数 387 Q值 [12.668775  3.600935]===> 步数 387 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 9 / 最高得分 9
# 步数 388 Q值 [12.575067   3.8939166]===> 步数 388 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 9 / 最高得分 9
# 步数 389 Q值 [12.576561  4.578685]===> 步数 389 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 9 / 最高得分 9
# 步数 390 Q值 [12.606403  5.239537]===> 步数 390 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 9 / 最高得分 9
# 步数 391 Q值 [12.678574  6.449505]===> 步数 391 / 本次行为 0 不跳 / 本次奖励 1 / Running   / 当前分数 10 / 最高得分 10
# 步数 392 Q值 [11.764337  6.263041]===> 步数 392 / 本次行为 0 不跳 / 本次奖励 0.1 / Running   / 当前分数 10 / 最高得分 10
# 步数 393 Q值 [11.804093   7.9396434]
